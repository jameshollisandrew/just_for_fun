# %%
import regex as r
import pandas as pd
import numpy as np

# %% [markdown]
# ## import data

# %%
df = pd.read_csv('elm_compiled_ss_re.csv', index_col = False)

# %%
len(df)
# Out:
# 3510

# %%
df.head()
# Out:
#                elm_id           subsequence                regex_pattern  \
# 0  CLV_C14_Caspase3-7  LHCMTGVDCTDGTRQKAAAL  [DSTE][^P][^DEWHFYC]D[GSAN]
# 1  CLV_C14_Caspase3-7  LPRPQSPSDLDSLDGRSLND  [DSTE][^P][^DEWHFYC]D[GSAN]
# 2  CLV_C14_Caspase3-7  PQSPSDLDSLDGRSLNDDGS  [DSTE][^P][^DEWHFYC]D[GSAN]
# 3  CLV_C14_Caspase3-7  VPPSVSKDVPDGPLLREETY  [DSTE][^P][^DEWHFYC]D[GSAN]
# 4  CLV_C14_Caspase3-7  PPKFTSQDSPDGQYENSEGG  [DSTE][^P][^DEWHFYC]D[GSAN]
#
#   pattern_match
# 0         DCTDG
# 1         SDLDS
# 2         SDLDS
# 3         DVPDG
# 4         TSQDS

# %%
def identify_submatches(exp_a, sub_a):
    """exp_a as input expression
       sub_a as input subject string"""
    
    input_exp = exp_a
    input_sub = sub_a
    
    # set patterns
    global M_G 
    global M_S
    global M_A
    global M_L
    global M_SQ
    
    M_G = r.compile('\^*\((?:[^()]+|(?R))*+\)({.+?})*\$*')
    M_S = r.compile('\^*\[.+?\]({.+?})*\$*')
    M_A = r.compile('\|')
    M_L = r.compile('\^*[.\w]({.+?})*\$*|\$')
    M_SQ = r.compile('\{(.),(.)\}')
    
    m_gro = '\^*\((?:[^()]+|(?R))*+\)({.+?})*\$*'
    m_set = '\^*\[.+?\]({.+?})*\$*'
    m_alt = '\|'
    m_lit = '\^*[.\w]({.+?})*\$*|\$'

    
    # PRINTOUT
    if (print_type == 1):
        print('\nExpression Input: {}\nSequence Input: {}'.format(exp_a, sub_a))
        
    if (print_type == 3):
        print('\n\nSTART ITERATION\nINPUTS\n  exp: {}\n  seq: {}'.format(exp_a, sub_a))
    
    
    # return the pattern match (USE IF SUB IS NOT MATCHED PRIMARY)
    if r.search(exp_a, sub_a) is not None:
        m = r.search(exp_a, sub_a)
        sub_a = m.group()
        # >>>PRINTOUT<<<
        if print_type == 3:
            print('\nSEQUENCE TYPE M\n  exp: {}\n  seq: {}'.format(exp_a, sub_a))
        
        elif m is None:
            print('Search expression: {} in sequence: {} returned no matches.\n\n'.format(exp_a, sub_a))
            return None
        
    if (print_type == 1):
        print('Subequence Match: {}'.format(sub_a))
            
            
            
    # check if main expression has unnested alternation
    if len(alt_states(exp_a)) > 0:
        # returns matching alternative
        exp_a = alt_evaluation(exp_a, sub_a)
        
        # >>>PRINTOUT<<<
        if print_type == 3:
            print('\nALTERNATION RETURN\n  exp: {}\n  seq: {}'.format(exp_a, sub_a))
    
    
    # get initial expression list
    exp_list = get_states(exp_a)
    
    
    # count possible expression constructions
    status, matched_tuples = finite_state(exp_list, sub_a)
    
    # >>>PRINTOUT<<<
    if print_type == 3:
        print('\nCONFIRM EXPRESSION\n  exp: {}'.format(matched_tuples))
        
        
    # index matches
    indexer(input_exp, input_sub, matched_tuples)

# %%
def indexer(exp_a, sub_a, matched_tuples):
    
    sub_length = len(sub_a)
    sub_b = r.search(exp_a, sub_a)
    adj = sub_b.start()
    sub_b = sub_b.group()
    
    print('')
    
    for pair in matched_tuples:
        pattern, match = pair
        
        start = adj
        adj = adj + len(match)
        end = adj
        index_pos = (start, end)
        
        sub_b = slice_string(match, sub_b)
        print('\t{}\t{}'.format(pattern, index_pos))

# %%
def strip_nest(s):
    
    s = s[1:]
    s = s[:-1]

    return s

# %%
def slice_string(p, s):
    
    pat = p
    string = s
    
    # handles escapes
    p = r.escape(p)
    # slice the input string on input pattern
    s = r.split(pattern = p, string = s, maxsplit = 1)[1]
    

    # >>>PRINTOUT<<<
    if print_type == 4:
        print('\nSLICE STRING\n  pat: {}\n  str: {}\n  slice: {}'.format(pat, string, s))
    
    
    return s

# %%
def alt_states(exp):
    # check each character in string
    idx = 0 # index tracker
    op = 0 # open parenth
    cp = 0 # close parenth
    free_alt = [] # amend with index position of unnested alt
    
    for c in exp:
        if c == '(':
            op += 1
        elif c == ')':
            cp += 1
        elif c == '|':
            if op == cp:
                free_alt.append(idx)
        if idx < len(exp)-1:
            idx+=1
    
    # split string if found
    alts = []
    
    if free_alt:
        _ = 0
        for i in free_alt:
            alts.append(exp[_:i])
            alts.append(exp[i+1:])
    
    # the truth value of this check can be checked against the length of the return
    # len(free_alt) > 0 means unnested "|" found
    return alts

# %%
def alt_evaluation(exp, sub):

    # >>>PRINTOUT<<<
    if print_type == 3:
        print('\nALTERNATION SELECTION\n  EXP: {}\n  SEQ: {}'.format(exp, sub))
    
    # gets alt index position
    alts = alt_states(exp)

    # variables for eval
    a_len = 0 # length of alternate match
    keep_len = 0 # length of return match
    keep = '' # return match string
    
    # evaluate alternatives
    for alt in alts:
        m = r.search(alt, sub)
        if m is not None:
            a_len = len(m.group())                             # length of match string

            # >>>PRINTOUT<<<
            if print_type == 3:
                print('  pat: {}\n  str: {}\n  len: {}'.format(alt, m.group(0), len(m.group(0))))
            
            if a_len >= keep_len:                              
                keep_len = a_len                               # sets alternate length to keep length
                exp = alt                                     # sets alt as keep variable

    # >>>PRINTOUT<<<
    if print_type == 3:
        print('  OUT: {}'.format(exp))                
                
    return exp

# %%
def get_states(exp):
    """counts number of subexpressions to be checked
       creates FSM"""
    
    # >>>PRINTOUT<<<
    if print_type == 3:
        print('\nGET STATES\n  EXP: {}'.format(exp))
        
    # List of possible subexpression regex matches
    m_gro = '\^*\((?:[^()]+|(?R))*+\)({.+?})*\$*'
    m_set = '\^*\[.+?\]({.+?})*\$*'
    m_alt = '\|'
    m_lit = '\^*[.\w]({.+?})*\$*|\$'
 
    
    # initialize capture list
    exp_list = []
    
    # loop through first level of subexpressions: 
    while exp != '':
        
        if r.match(m_gro, exp):
            _ = r.match(m_gro, exp).group(0)
            exp_list.append(_)
            exp = slice_string(_, exp)
        
        elif r.match(m_set, exp):
            _ = r.match(m_set, exp).group(0)
            exp_list.append(_)
            exp = slice_string(_, exp)
            

        
        elif r.match(m_alt, exp):
            _ = ''
        
        elif r.match(m_lit, exp):
            _ = r.match(m_lit, exp).group(0)
            exp_list.append(_)
            exp = slice_string(_, exp)
        
        else:
            print('ERROR getting states')
            break
    
    n_states = len(exp_list)
    
    
    # >>>PRINTOUT<<<
    if print_type == 3:
        print('GET STATES OUT\n  states:\n  {}\n  # of states: {}'.format(exp_list, n_states))

    
    return exp_list

# %%
def finite_state(exp_list, seq, level = 0, pattern_builder = '', iter_count = 0, pat_match = [], seq_match = []):
    
    
    # >>>PRINTOUT<<<
    if (print_type == 3):
        print('\nSTARTING MACHINE\n  EXP: {}\n  SEQ: {}\n  LEVEL: {}\n  matched: {}\n  pat_match: {}'.format(exp_list, seq, level, pattern_builder, pat_match))
    
    
    # patterns
    m_gro = '\^*\((?:[^()]+|(?R))*+\)({.+?})*\$*'
    m_set = '\^*\[.+?\]({.+?})*\$*'
    m_alt = '\|'
    m_squ = '\{(.),(.)\}'
    m_lit = '\^*[.\w]({.+?})*\$*|\$'

    
    # set state, n_state
    state = 0
    n_states = len(exp_list)
    #save_state = []
    #save_expression = []
    
 
    # temp exp
    local_seq = seq

    # >>>PRINTOUT<<<
    if print_type == 3:
        print('\n  >>>MACHINE START')



    # set failure cap so no endless loop
    failure_cap = 1000

    # since len(exp_list) returns + 1 over iteration (0 index) use the last 'state' as success state
    while state != n_states:
        
        for exp in exp_list:
            
            # iterations
            iter_count+=1
            
            # >>>PRINTOUT<<<
            if print_type == 3:
                print('  iteration count: {}'.format(iter_count))
            
            # >>>PRINTOUT<<<
            if print_type == 3:
                print('\n  evaluating: {}\n  for string: {}'.format(exp, local_seq))
                 
                    
            # alternation reset
            if len(alt_states(exp)) > 0:
                
                # get operand options
                operands = alt_states(exp)               
                # create temporary exp list
                temp_list = exp_list[state+1:]
                # add level
                level = level + 1                   
                
                # >>>PRINTOUT<<<
                if print_type == 3:
                    print('  ALT MATCH: {}\n  state: {}\n  opers returned: {}\n  level in: {}'.format(exp, state, operands, level))
                    
                # compile local altneration
                for oper in operands:
                    # get substates
                    _ = get_states(oper)
                    # compile list
                    oper_list = _ + temp_list
                    # send to finite_state, sublevel                    
                    alt_status, pats = finite_state(oper_list, local_seq, level = level, pattern_builder=pattern_builder, iter_count=iter_count, pat_match=pat_match)
                    if alt_status == 'success':
                        return alt_status, pats

                    
            # group cycle
            elif r.match(m_gro, exp) is not None:
                # get operand options
                operands = group_states(exp)
                # create temporary exp list
                temp_list = exp_list[state+1:]
                # add level
                level = level + 1
                
                # >>>PRINTOUT<<<
                if print_type == 3:
                    print('  GROUP MATCH: {}\n  state: {}\n  opers returned: {}\n  level in: {}'.format(exp, state, operands, level))
                    
                # compile local
                oper_list = operands + temp_list
                # send to finite_state, sublevel
                group_status, pats = finite_state(oper_list, local_seq, level=level, pattern_builder=pattern_builder, iter_count=iter_count, pat_match=pat_match)
                if group_status == 'success':
                    return group_status, pats
    
    
            # quantifier reset
            elif r.search(m_squ, exp) is not None:
                # get operand options
                operands = quant_states(exp)
                # create temporary exp list
                temp_list = exp_list[state+1:]
                # add level
                level = level + 1

                # >>>PRINTOUT<<<
                if print_type == 3:
                    print('  QUANT MATCH: {}\n  state: {}\n  opers returned: {}\n  level in: {}'.format(exp, state, operands, level))
                
                # compile local
                for oper in reversed(operands):
                    # compile list
                    oper_list = [oper] + temp_list
                    # send to finite_state, sublevel
                    quant_status, pats = finite_state(oper_list, local_seq, level=level, pattern_builder=pattern_builder, iter_count=iter_count, pat_match=pat_match)
                    if quant_status == 'success':
                        return quant_status, pats
                
                
            # record literal
            elif r.match(exp, local_seq) is not None:
                # add to local pattern
                m = r.match(exp, local_seq).group(0)
                local_seq = slice_string(m, local_seq)
                
                # >>>PRINTOUT<<<
                if print_type == 3:
                    print('  state transition: {}\n  state {} ==> {} of {}'.format(exp, state, state+1, n_states))
                
                # iterate state for match
                pattern_builder = pattern_builder + exp
                pat_match = pat_match + [(exp, m)]
                state += 1
            elif r.match(exp, local_seq) is None:
                # >>>PRINTOUT<<<
                if print_type == 3:
                    print('  Return FAIL on {}, level: {}, state: {}'.format(exp, level, state))
                status = 'fail'
                return status, pattern_builder
                
                
            # machine success
            if state == n_states:

                # >>>PRINTOUT<<<
                if print_type == 3:
                    print('  MACHINE SUCCESS\n  level: {}\n  state: {}\n  exp: {}'.format(level, state, pattern_builder))
                    
                status = 'success'
                return status, pat_match

            # timeout
            if iter_count == failure_cap:
                state = n_states
                
                # >>>PRINTOUT<<<
                if print_type == 3:
                    print('===============\nFAILURE CAP MET\n  level: {}\n  exp state: {}\n==============='.format(level, state))
                break

# %%
def group_states(exp):

    
    # patterns
    m_gro = '\^*\((?:[^()]+|(?R))*+\)({.+?})*\$*'
    m_set = '\^*\[.+?\]({.+?})*\$*'
    m_alt = '\|'
    m_squ = '\{(.),(.)\}'
    m_lit = '\^*[.\w]({.+?})*\$*'
    
    ret_list = []
    
    # iterate over groups
    groups = r.finditer(m_gro, exp)

    for gr in groups:
        _ = strip_nest(gr.group())      
        
        # alternation reset
        if r.search(m_alt, _):
            ret_list.append(_)
        
        else:
            _ = get_states(_)
            for thing in _:
                ret_list.append(thing)

    return(ret_list)

# %%
def quant_states(exp):
    
    
    # >>>PRINTOUT<<<
    if print_type == 4:
        print('\nGET QUANT STATES\n  EXP: {}'.format(exp))
    
    squ_opr = '(.+)\{.,.\}'
    m_squ = '\{(.),(.)\}'

    # create states
    states_list = []    
    
    # get operand
    operand_obj = r.finditer(squ_opr, exp)
    for match in operand_obj:
        operand = match.group(1)
    
    # get repetitions
    fa = r.findall(m_squ, exp)
    for m, n in fa:
        # loop through range
        for x in range(int(m), (int(n)+1)):
            # construct string
            _ = operand + '{' + str(x) + '}'
            # append to list
            states_list.append(_)
            
    # >>>PRINTOUT<<<
    if print_type == 4:
        print('  QUANT OUT: {}\n'.format(states_list))
        
    return states_list

# %%
# %%time

print_type = 1
"""0:    
   1: includes input
   2: 
   3: all output prints on """


dataframe_counting = 0
for x in range(len(df)):
    
    try:
        df_expression = df.iloc[x, 2]
        df_subsequence = df.iloc[x, 1]

        # call function
        identify_submatches(df_expression, df_subsequence)
        print(dataframe_counting)
        dataframe_counting += 1
    except:
        pass
# Out:
# Expression Input: [DSTE][^P][^DEWHFYC]D[GSAN]
# Sequence Input: LHCMTGVDCTDGTRQKAAAL
# Subequence Match: DCTDG
#
# 	[DSTE]	(7, 8)
# 	[^P]	(8, 9)
# 	[^DEWHFYC]	(9, 10)
# 	D	(10, 11)
# 	[GSAN]	(11, 12)
# 0
#
# Expression Input: [DSTE][^P][^DEWHFYC]D[GSAN]
# Sequence Input: LPRPQSPSDLDSLDGRSLND
# Subequence Match: SDLDS
#
# 	[DSTE]	(7, 8)
# 	[^P]	(8, 9)
# 	[^DEWHFYC]	(9, 10)
# 	D	(10, 11)
# 	[GSAN]	(11, 12)
# 1
#
# Expression Input: [DSTE][^P][^DEWHFYC]D[GSAN]
# Sequence Input: PQSPSDLDSLDGRSLNDDGS
# Subequence Match: SDLDS
#
# 	[DSTE]	(4, 5)
# 	[^P]	(5, 6)
# 	[^DEWHFYC]	(6, 7)
# 	D	(7, 8)
# 	[GSAN]	(8, 9)
# 2
#
# Expression Input: [DSTE][^P][^DEWHFYC]D[GSAN]
# Sequence Input: VPPSVSKDVPDGPLLREETY
# Subequence Match: DVPDG
#
# 	[DSTE]	(7, 8)
# 	[^P]	(8, 9)
# 	[^DEWHFYC]	(9, 10)
# 	D	(10, 11)
# 	[GSAN]	(11, 12)
# 3
#
# Expression Input: [DSTE][^P][^DEWHFYC]D[GSAN]
# Sequence Input: PPKFTSQDSPDGQYENSEGG
# Subequence Match: TSQDS
#
# 	[DSTE]	(4, 5)
# 	[^P]	(5, 6)
# 	[^DEWHFYC]	(6, 7)
# 	D	(7, 8)
# 	[GSAN]	(8, 9)
# 4
#
# Expression Input: [DSTE][^P][^DEWHFYC]D[GSAN]
# Sequence Input: PLLPPEDDTRDNVYYYDEEG
# Subequence Match: DTRDN
#
# 	[DSTE]	(7, 8)
# 	[^P]	(8, 9)
# 	[^DEWHFYC]	(9, 10)
# 	D	(10, 11)
# 	[GSAN]	(11, 12)
# 5
#
# Expression Input: [DSTE][^P][^DEWHFYC]D[GSAN]
# Sequence Input: AGGEENMTETDAFYKREMFD
# Subequence Match: TETDA
#
# 	[DSTE]	(7, 8)
# 	[^P]	(8, 9)
# 	[^DEWHFYC]	(9, 10)
# 	D	(10, 11)
# 	[GSAN]	(11, 12)
# 6
#
# Expression Input: [DSTE][^P][^DEWHFYC]D[GSAN]
# Sequence Input: DVPVIPLDVVDNQTEKLDTN
# Subequence Match: DVVDN
#
# 	[DSTE]	(7, 8)
# 	[^P]	(8, 9)
# 	[^DEWHFYC]	(9, 10)
# 	D	(10, 11)
# 	[GSAN]	(11, 12)
# 7
#
# Expression Input: [DSTE][^P][^DEWHFYC]D[GSAN]
# Sequence Input: EKLDTNITEVDAASVYTLPA
# Subequence Match: TEVDA
#
# 	[DSTE]	(7, 8)
# 	[^P]	(8, 9)
# 	[^DEWHFYC]	(9, 10)
# 	D	(10, 11)
# 	[GSAN]	(11, 12)
# 8
#
# Expression Input: [DSTE][^P][^DEWHFYC]D[GSAN]
# Sequence Input: QEGLRTFDQLDAISSLPTPS
# Subequence Match: DQLDA
#
# 	[DSTE]	(7, 8)
# 	[^P]	(8, 9)
# 	[^DEWHFYC]	(9, 10)
# 	D	(10, 11)
# 	[GSAN]	(11, 12)
# 9
#
# Expression Input: [DSTE][^P][^DEWHFYC]D[GSAN]
# Sequence Input: IHISQVISEVDGNRMTLSQE
# Subequence Match: SEVDG
#
# 	[DSTE]	(7, 8)
# 	[^P]	(8, 9)
# 	[^DEWHFYC]	(9, 10)
# 	D	(10, 11)
# 	[GSAN]	(11, 12)
# 10
#
# Expression Input: [DSTE][^P][^DEWHFYC]D[GSAN]
# Sequence Input: DPNVISQEEADSPSDSGQGS
# Subequence Match: EEADS
#
# 	[DSTE]	(7, 8)
# 	[^P]	(8, 9)
# 	[^DEWHFYC]	(9, 10)
# 	D	(10, 11)
# 	[GSAN]	(11, 12)
# 11
#
# Expression Input: [DSTE][^P][^DEWHFYC]D[GSAN]
# Sequence Input: HGMLEMPDLRDGSNVIVTER
# Subequence Match: DLRDG
#
# 	[DSTE]	(7, 8)
# 	[^P]	(8, 9)
# 	[^DEWHFYC]	(9, 10)
# 	D	(10, 11)
# 	[GSAN]	(11, 12)
# 12
#
# Expression Input: [DSTE][^P][^DEWHFYC]D[GSAN]
# Sequence Input: STGGTNKDYADGAISMNFLD
# Subequence Match: DYADG
#
# 	[DSTE]	(7, 8)
# 	[^P]	(8, 9)
# 	[^DEWHFYC]	(9, 10)
# 	D	(10, 11)
# 	[GSAN]	(11, 12)
# 13
#
# Expression Input: [DSTE][^P][^DEWHFYC]D[GSAN]
# Sequence Input: HVEEDDDDELDSKLNYKPPP
# Subequence Match: DELDS
#
# 	[DSTE]	(7, 8)
# 	[^P]	(8, 9)
# 	[^DEWHFYC]	(9, 10)
# 	D	(10, 11)
# 	[GSAN]	(11, 12)
# 14
#
# Expression Input: [DSTE][^P][^DEWHFYC]D[GSAN]
# Sequence Input: FLDVSGMSLLDSNNTSVCPS
# Subequence Match: SLLDS
#
# 	[DSTE]	(7, 8)
# 	[^P]	(8, 9)
# 	[^DEWHFYC]	(9, 10)
# 	D	(10, 11)
# 	[GSAN]	(11, 12)
# 15
#
# Expression Input: [DSTE][^P][^DEWHFYC]D[GSAN]
# Sequence Input: SGSEFEISFPDSPGSQAQVD
# Subequence Match: SFPDS
#
# 	[DSTE]	(7, 8)
# 	[^P]	(8, 9)
# 	[^DEWHFYC]	(9, 10)
# 	D	(10, 11)
# 	[GSAN]	(11, 12)
# 16
#
# Expression Input: [DSTE][^P][^DEWHFYC]D[GSAN]
# Sequence Input: VDHLPRLTLPDGLTSAASPE
# Subequence Match: TLPDG
#
# 	[DSTE]	(7, 8)
# 	[^P]	(8, 9)
# 	[^DEWHFYC]	(9, 10)
# 	D	(10, 11)
# 	[GSAN]	(11, 12)
# 17
#
# Expression Input: [DSTE][^P][^DEWHFYC]D[GSAN]
# Sequence Input: VPSDPAMDLNDGTQASSPIS
# Subequence Match: DLNDG
#
# 	[DSTE]	(7, 8)
# 	[^P]	(8, 9)
# 	[^DEWHFYC]	(9, 10)
# 	D	(10, 11)
# 	[GSAN]	(11, 12)
# 18
#
# Expression Input: [DSTE][^P][^DEWHFYC]D[GSAN]
# Sequence Input: EATHDLNSSTDSAASASAAS
# Subequence Match: SSTDS
#
# 	[DSTE]	(7, 8)
# 	[^P]	(8, 9)
# 	[^DEWHFYC]	(9, 10)
# 	D	(10, 11)
# 	[GSAN]	(11, 12)
# 19
#
# Expression Input: [DSTE][^P][^DEWHFYC]D[GSAN]
# Sequence Input: QAEMLQMDLIDATGDTPGAE
# Subequence Match: DLIDA
#
# 	[DSTE]	(7, 8)
# 	[^P]	(8, 9)
# 	[^DEWHFYC]	(9, 10)
# 	D	(10, 11)
# 	[GSAN]	(11, 12)
# 20
#
# Expression Input: [DSTE][^P][^DEWHFYC]D[GSAN]
# Sequence Input: PCFGDYSDESDSATVYDNCA
# Subequence Match: DESDS
#
# 	[DSTE]	(7, 8)
# 	[^P]	(8, 9)
# 	[^DEWHFYC]	(9, 10)
# 	D	(10, 11)
# 	[GSAN]	(11, 12)
# 21
#
# Expression Input: [DSTE][^P][^DEWHFYC]D[GSAN]
# Sequence Input: KTGVAGEDMQDNSGTYGKIW
# Subequence Match: DMQDN
#
# 	[DSTE]	(7, 8)
# 	[^P]	(8, 9)
# 	[^DEWHFYC]	(9, 10)
# 	D	(10, 11)
# 	[GSAN]	(11, 12)
# 22
#
# Expression Input: [DSTE][^P][^DEWHFYC]D[GSAN]
# Sequence Input: VPAPVGDSHVDGAAKSLDKQ
# Subequence Match: SHVDG
#
# 	[DSTE]	(7, 8)
# 	[^P]	(8, 9)
# 	[^DEWHFYC]	(9, 10)
# 	D	(10, 11)
# 	[GSAN]	(11, 12)
# 23
#
# Expression Input: [DSTE][^P][^DEWHFYC]D[GSAN]
# Sequence Input: SEGKRKGDEVDGVDEVAKKK
# Subequence Match: DEVDG
#
# 	[DSTE]	(7, 8)
# 	[^P]	(8, 9)
# 	[^DEWHFYC]	(9, 10)
# 	D	(10, 11)
# 	[GSAN]	(11, 12)
# 24
#
# Expression Input: [DSTE][^P][^DEWHFYC]D[GSAN]
# Sequence Input: KRLGLPGDEVDNKVKGAAGR
# Subequence Match: DEVDN
#
# 	[DSTE]	(7, 8)
# 	[^P]	(8, 9)
# 	[^DEWHFYC]	(9, 10)
# 	D	(10, 11)
# 	[GSAN]	(11, 12)
# 25
#
# Expression Input: [DSTE][^P][^DEWHFYC]D[GSAN]
# Sequence Input: PDHYRYSDTTDSDPENEPFD
# Subequence Match: DTTDS
#
# 	[DSTE]	(7, 8)
# 	[^P]	(8, 9)
# 	[^DEWHFYC]	(9, 10)
# 	D	(10, 11)
# 	[GSAN]	(11, 12)
# 26
#
# Expression Input: [DSTE][^P][^DEWHFYC]D[GSAN]
# Sequence Input: HDKTLQTDSIDSFETQRTPR
# Subequence Match: DSIDS
#
# 	[DSTE]	(7, 8)
# 	[^P]	(8, 9)
# 	[^DEWHFYC]	(9, 10)
# 	D	(10, 11)
# 	[GSAN]	(11, 12)
# 27
#
# Expression Input: [DSTE][^P][^DEWHFYC]D[GSAN]
# Sequence Input: RFDIEGSDEADGSKHLPGES
# Subequence Match: DEADG
#
# 	[DSTE]	(7, 8)
# 	[^P]	(8, 9)
# 	[^DEWHFYC]	(9, 10)
# 	D	(10, 11)
# 	[GSAN]	(11, 12)
# 28
#
# Expression Input: [DSTE][^P][^DEWHFYC]D[GSAN]
# Sequence Input: VASFPSADETDGNLPESRIE
# Subequence Match: DETDG
#
# 	[DSTE]	(7, 8)
# 	[^P]	(8, 9)
# 	[^DEWHFYC]	(9, 10)
# 	D	(10, 11)
# 	[GSAN]	(11, 12)
# 29
#
# Expression Input: [DSTE][^P][^DEWHFYC]D[GSAN]
# Sequence Input: PPGELGPDGPDGPEEKGRDR
# Subequence Match: DGPDG
#
# 	[DSTE]	(7, 8)
# 	[^P]	(8, 9)
# 	[^DEWHFYC]	(9, 10)
# 	D	(10, 11)
# 	[GSAN]	(11, 12)
# 30
#
# Expression Input: [DSTE][^P][^DEWHFYC]D[GSAN]
# Sequence Input: TGETTSFDEVDGVTSKSIIG
# Subequence Match: DEVDG
#
# 	[DSTE]	(7, 8)
# 	[^P]	(8, 9)
# 	[^DEWHFYC]	(9, 10)
# 	D	(10, 11)
# 	[GSAN]	(11, 12)
# 31
#
# Expression Input: [DSTE][^P][^DEWHFYC]D[GSAN]
# Sequence Input: QDDDARTDAVDSVVRDIQNT
# Subequence Match: DAVDS
#
# 	[DSTE]	(7, 8)
# 	[^P]	(8, 9)
# 	[^DEWHFYC]	(9, 10)
# 	D	(10, 11)
# 	[GSAN]	(11, 12)
# 32
#
# Expression Input: [DSTE][^P][^DEWHFYC]D[GSAN]
# Sequence Input: VYGMMPRDETDSKTASPWKS
# Subequence Match: DETDS
#
# 	[DSTE]	(7, 8)
# 	[^P]	(8, 9)
# 	[^DEWHFYC]	(9, 10)
# 	D	(10, 11)
# 	[GSAN]	(11, 12)
# 33
#
# Expression Input: [DSTE][^P][^DEWHFYC]D[GSAN]
# Sequence Input: LNTEDKGDSLDSVEALIKKH
# Subequence Match: DKGDS
#
# 	[DSTE]	(4, 5)
# 	[^P]	(5, 6)
# 	[^DEWHFYC]	(6, 7)
# 	D	(7, 8)
# 	[GSAN]	(8, 9)
# 34
#
# Expression Input: [DSTE][^P][^DEWHFYC]D[GSAN]
# Sequence Input: SQEGKSTDEVDSKRLTVQTK
# Subequence Match: DEVDS
#
# 	[DSTE]	(7, 8)
# 	[^P]	(8, 9)
# 	[^DEWHFYC]	(9, 10)
# 	D	(10, 11)
# 	[GSAN]	(11, 12)
# 35
#
# Expression Input: [DSTE][^P][^DEWHFYC]D[GSAN]
# Sequence Input: SGGSGSDSEPDSPVFEDSKA
# Subequence Match: SGSDS
#
# 	[DSTE]	(3, 4)
# 	[^P]	(4, 5)
# 	[^DEWHFYC]	(5, 6)
# 	D	(6, 7)
# 	[GSAN]	(7, 8)
# 36
#
# Expression Input: [DSTE][^P][^DEWHFYC]D[GSAN]
# Sequence Input: LDDAKVKDEPDSPPVALGMV
# Subequence Match: DEPDS
#
# 	[DSTE]	(7, 8)
# 	[^P]	(8, 9)
# 	[^DEWHFYC]	(9, 10)
# 	D	(10, 11)
# 	[GSAN]	(11, 12)
# 37
#
# Expression Input: [DSTE][^P][^DEWHFYC]D[GSAN]
# Sequence Input: EEENSDEDELDSHTMVKTSV
# Subequence Match: DELDS
#
# 	[DSTE]	(7, 8)
# 	[^P]	(8, 9)
# 	[^DEWHFYC]	(9, 10)
# 	D	(10, 11)
# 	[GSAN]	(11, 12)
# 38
#
# Expression Input: [DSTE][^P][^DEWHFYC]D[GSAN]
# Sequence Input: DEENSEEDEMDSGTMVRAVG
# Subequence Match: DEMDS
#
# 	[DSTE]	(7, 8)
# 	[^P]	(8, 9)
# 	[^DEWHFYC]	(9, 10)
# 	D	(10, 11)
# 	[GSAN]	(11, 12)
# 39
#
# Expression Input: [DSTE][^P][^DEWHFYC]D[GSAN]
# Sequence Input: DHCITSSDMMDSSSFSNLDL
# Subequence Match: DMMDS
#
# 	[DSTE]	(7, 8)
# 	[^P]	(8, 9)
# 	[^DEWHFYC]	(9, 10)
# 	D	(10, 11)
# 	[GSAN]	(11, 12)
# 40
#
# Expression Input: [ILV]..R[VF][GS].
# Sequence Input: RPIGPEIQNRFGENAEERIP
# Subequence Match: IQNRFGE
#
# 	[ILV]	(6, 7)
# 	.	(7, 8)
# 	.	(8, 9)
# 	R	(9, 10)
# 	[VF]	(10, 11)
# 	[GS]	(11, 12)
# 	.	(12, 13)
# 41
#
# Expression Input: [ILV]..R[VF][GS].
# Sequence Input: KFATNVIANRFGNDATRTIP
# Subequence Match: IANRFGN
#
# 	[ILV]	(6, 7)
# 	.	(7, 8)
# 	.	(8, 9)
# 	R	(9, 10)
# 	[VF]	(10, 11)
# 	[GS]	(11, 12)
# 	.	(12, 13)
# 42
#
# Expression Input: [ILV]..R[VF][GS].
# Sequence Input: KPLGVALTNRFGEDADERID
# Subequence Match: LTNRFGE
#
# 	[ILV]	(6, 7)
# 	.	(7, 8)
# 	.	(8, 9)
# 	R	(9, 10)
# 	[VF]	(10, 11)
# 	[GS]	(11, 12)
# 	.	(12, 13)
# 43
#
# Expression Input: [ILV]..R[VF][GS].
# Sequence Input: RAIGQSLQTRFSTNISTRVP
# Subequence Match: LQTRFST
#
# 	[ILV]	(6, 7)
# 	.	(7, 8)
# 	.	(8, 9)
# 	R	(9, 10)
# 	[VF]	(10, 11)
# 	[GS]	(11, 12)
# 	.	(12, 13)
# 44
#
# Expression Input: [ILV]..R[VF][GS].
# Sequence Input: RNDTEEVGNRFSKDVDLKIP
# Subequence Match: VGNRFSK
#
# 	[ILV]	(6, 7)
# 	.	(7, 8)
# 	.	(8, 9)
# 	R	(9, 10)
# 	[VF]	(10, 11)
# 	[GS]	(11, 12)
# 	.	(12, 13)
# 45
#
# Expression Input: [ILV]..R[VF][GS].
# Sequence Input: RSVATQVFNRFGDDTESKLP
# Subequence Match: VFNRFGD
#
# 	[ILV]	(6, 7)
# 	.	(7, 8)
# 	.	(8, 9)
# 	R	(9, 10)
# 	[VF]	(10, 11)
# 	[GS]	(11, 12)
# 	.	(12, 13)
# 46
#
# Expression Input: [ILV]..R[VF][GS].
# Sequence Input: KAIGVQVSNRFGEETKSKIP
# Subequence Match: VSNRFGE
#
# 	[ILV]	(6, 7)
# 	.	(7, 8)
# 	.	(8, 9)
# 	R	(9, 10)
# 	[VF]	(10, 11)
# 	[GS]	(11, 12)
# 	.	(12, 13)
# 47
#
# Expression Input: [ILV]..R[VF][GS].
# Sequence Input: KNVAVEISNRFGEDDSETVT
# Subequence Match: ISNRFGE
#
# 	[ILV]	(6, 7)
# 	.	(7, 8)
# 	.	(8, 9)
# 	R	(9, 10)
# 	[VF]	(10, 11)
# 	[GS]	(11, 12)
# 	.	(12, 13)
# 48
#
# Expression Input: [ILV]..R[VF][GS].
# Sequence Input: DEAPPSVATRVGVSPSVNLP
# Subequence Match: VATRVGV
#
# 	[ILV]	(6, 7)
# 	.	(7, 8)
# 	.	(8, 9)
# 	R	(9, 10)
# 	[VF]	(10, 11)
# 	[GS]	(11, 12)
# 	.	(12, 13)
# 49
#
# Expression Input: [ILV]..R[VF][GS].
# Sequence Input: ANNGIELNNRFGDDASEKIP
# Subequence Match: LNNRFGD
#
# 	[ILV]	(6, 7)
# 	.	(7, 8)
# 	.	(8, 9)
# 	R	(9, 10)
# 	[VF]	(10, 11)
# 	[GS]	(11, 12)
# 	.	(12, 13)
# 50
#
# Expression Input: [ILV]..R[VF][GS].
# Sequence Input: RAIGAELQNRFSNDAEQRIP
# Subequence Match: LQNRFSN
#
# 	[ILV]	(6, 7)
# 	.	(7, 8)
# 	.	(8, 9)
# 	R	(9, 10)
# 	[VF]	(10, 11)
# 	[GS]	(11, 12)
# 	.	(12, 13)
# 51
#
# Expression Input: [ILV]..R[VF][GS].
# Sequence Input: RPIGSEVQSRFGEKAEKRIP
# Subequence Match: VQSRFGE
#
# 	[ILV]	(6, 7)
# 	.	(7, 8)
# 	.	(8, 9)
# 	R	(9, 10)
# 	[VF]	(10, 11)
# 	[GS]	(11, 12)
# 	.	(12, 13)
# 52
#
# Expression Input: (.RK)|(RR[^KR])
# Sequence Input: YKRYGGFLRRIRPKLKWDNQ
# Subequence Match: RRI
#
# 	R	(8, 9)
# 	R	(9, 10)
# 	[^KR]	(10, 11)
# 53
#
# Expression Input: (.RK)|(RR[^KR])
# Sequence Input: SNPAMAPRERKAGCKNFFWK
# Subequence Match: ERK
#
# 	.	(8, 9)
# 	R	(9, 10)
# 	K	(10, 11)
# 54
#
# Expression Input: R.[RK]R.
# Sequence Input: GRWRGRSRSRRAATSRPERV
# Subequence Match: RSRRA
#
# 	R	(7, 8)
# 	.	(8, 9)
# 	[RK]	(9, 10)
# 	R	(10, 11)
# 	.	(11, 12)
# 55
#
# Expression Input: R.[RK]R.
# Sequence Input: GNTSSSSRRRRDIQYHKLPV
# Subequence Match: RRRRD
#
# 	R	(7, 8)
# 	.	(8, 9)
# 	[RK]	(9, 10)
# 	R	(10, 11)
# 	.	(11, 12)
# 56
#
# Expression Input: R.[RK]R.
# Sequence Input: PVPPPATRRRRAVPIAVWLV
# Subequence Match: RRRRA
#
# 	R	(7, 8)
# 	.	(8, 9)
# 	[RK]	(9, 10)
# 	R	(10, 11)
# 	.	(11, 12)
# 57
#
# Expression Input: R.[RK]R.
# Sequence Input: AKRRVVQREKRAVGIGALFL
# Subequence Match: REKRA
#
# 	R	(7, 8)
# 	.	(8, 9)
# 	[RK]	(9, 10)
# 	R	(10, 11)
# 	.	(11, 12)
# 58
#
# Expression Input: R.[RK]R.
# Sequence Input: AKRRVVQREKRAVGIGALFL
# Subequence Match: REKRA
#
# 	R	(7, 8)
# 	.	(8, 9)
# 	[RK]	(9, 10)
# 	R	(10, 11)
# 	.	(11, 12)
# 59
#
# Expression Input: R.[RK]R.
# Sequence Input: NVTLSKKRKRRFLGFLLGVG
# Subequence Match: RKRRF
#
# 	R	(7, 8)
# 	.	(8, 9)
# 	[RK]	(9, 10)
# 	R	(10, 11)
# 	.	(11, 12)
# 60
#
# Expression Input: R.[RK]R.
# Sequence Input: TPAAVLRRRRRDAGNATTPV
# Subequence Match: RRRRR
#
# 	R	(6, 7)
# 	.	(7, 8)
# 	[RK]	(8, 9)
# 	R	(9, 10)
# 	.	(10, 11)
# 61
#
# Expression Input: R.[RK]R.
# Sequence Input: SQTGEHRRDKRSVALAPHVG
# Subequence Match: RDKRS
#
# 	R	(7, 8)
# 	.	(8, 9)
# 	[RK]	(9, 10)
# 	R	(10, 11)
# 	.	(11, 12)
# 62
#
# Expression Input: R.[RK]R.
# Sequence Input: KITNGTRRFRRSITENVANC
# Subequence Match: RFRRS
#
# 	R	(7, 8)
# 	.	(8, 9)
# 	[RK]	(9, 10)
# 	R	(10, 11)
# 	.	(11, 12)
# 63
#
# Expression Input: R.[RK]R.
# Sequence Input: LLTNPSSRRKRSLIEDLLFT
# Subequence Match: RRKRS
#
# 	R	(7, 8)
# 	.	(8, 9)
# 	[RK]	(9, 10)
# 	R	(10, 11)
# 	.	(11, 12)
# 64
#
# Expression Input: R.[RK]R.
# Sequence Input: GLITGGRRTRREAIVNAQPK
# Subequence Match: RTRRE
#
# 	R	(7, 8)
# 	.	(8, 9)
# 	[RK]	(9, 10)
# 	R	(10, 11)
# 	.	(11, 12)
# 65
#
# Expression Input: R.[RK]R.
# Sequence Input: RHKRSAKRTKRASATQLYKT
# Subequence Match: RHKRS
#
# 	R	(0, 1)
# 	.	(1, 2)
# 	[RK]	(2, 3)
# 	R	(3, 4)
# 	.	(4, 5)
# 66
#
# Expression Input: R.[RK]R.
# Sequence Input: EPKTSVVRVRRELLPTQGPT
# Subequence Match: RVRRE
#
# 	R	(7, 8)
# 	.	(8, 9)
# 	[RK]	(9, 10)
# 	R	(10, 11)
# 	.	(11, 12)
# 67
#
# Expression Input: [KR]R.
# Sequence Input: QAITSSKAKRDVISQIGDGQ
# Subequence Match: KRD
#
# 	[KR]	(8, 9)
# 	R	(9, 10)
# 	.	(10, 11)
# 68
#
# Expression Input: KR.
# Sequence Input: PEPSPREGKRSYSMEHFRWG
# Subequence Match: KRS
#
# 	K	(8, 9)
# 	R	(9, 10)
# 	.	(10, 11)
# 69
#
# Expression Input: KR.
# Sequence Input: AEAFPLEFKRELEGERPLGL
# Subequence Match: KRE
#
# 	K	(8, 9)
# 	R	(9, 10)
# 	.	(10, 11)
# 70
#
# Expression Input: KR.
# Sequence Input: RWSNPPKDKRYGGFMTSEKS
# Subequence Match: KRY
#
# 	K	(8, 9)
# 	R	(9, 10)
# 	.	(10, 11)
# 71
#
# Expression Input: KR.
# Sequence Input: EEDLRKQAKRYGGFLRKYPK
# Subequence Match: KRY
#
# 	K	(8, 9)
# 	R	(9, 10)
# 	.	(10, 11)
# 72
#
# Expression Input: KR.
# Sequence Input: SAEWDVFTKRSSLTDLISPV
# Subequence Match: KRS
#
# 	K	(8, 9)
# 	R	(9, 10)
# 	.	(10, 11)
# 73
#
# Expression Input: KR.
# Sequence Input: GPEWSQPMKRLTLGNTTSSV
# Subequence Match: KRL
#
# 	K	(8, 9)
# 	R	(9, 10)
# 	.	(10, 11)
# 74
#
# Expression Input: R...[KR]R.
# Sequence Input: GHALTRRRRAKRSPKHHSQR
# Subequence Match: RRRAKRS
#
# 	R	(6, 7)
# 	.	(7, 8)
# 	.	(8, 9)
# 	.	(9, 10)
# 	[KR]	(10, 11)
# 	R	(11, 12)
# 	.	(12, 13)
# 75
#
# Expression Input: [RK].[AILMFV][LTKF].
# Sequence Input: VSPANQRRHLLGFSAKEAQD
# Subequence Match: RHLLG
#
# 	[RK]	(7, 8)
# 	.	(8, 9)
# 	[AILMFV]	(9, 10)
# 	[LTKF]	(10, 11)
# 	.	(11, 12)
# 76
#
# Expression Input: [RK].[AILMFV][LTKF].
# Sequence Input: HPHSGSGRSVLSFESGSGGW
# Subequence Match: RSVLS
#
# 	[RK]	(7, 8)
# 	.	(8, 9)
# 	[AILMFV]	(9, 10)
# 	[LTKF]	(10, 11)
# 	.	(11, 12)
# 77
#
# Expression Input: S[IVLMH]E[IVPFMLYAQR]GR.
# Sequence Input: DNQSQISIEVGRDAPAAAAT
# Subequence Match: SIEVGRD
#
# 	S	(6, 7)
# 	[IVLMH]	(7, 8)
# 	E	(8, 9)
# 	[IVPFMLYAQR]	(9, 10)
# 	G	(10, 11)
# 	R	(11, 12)
# 	.	(12, 13)
# 78
#
# Expression Input: S[IVLMH]E[IVPFMLYAQR]GR.
# Sequence Input: SSSSTRSHEYGRKSFRNNKN
# Subequence Match: SHEYGRK
#
# 	S	(6, 7)
# 	[IVLMH]	(7, 8)
# 	E	(8, 9)
# 	[IVPFMLYAQR]	(9, 10)
# 	G	(10, 11)
# 	R	(11, 12)
# 	.	(12, 13)
# 79
#
# Expression Input: S[IVLMH]E[IVPFMLYAQR]GR.
# Sequence Input: AAPWDTSLEVGRRFSPDEDF
# Subequence Match: SLEVGRR
#
# 	S	(6, 7)
# 	[IVLMH]	(7, 8)
# 	E	(8, 9)
# 	[IVPFMLYAQR]	(9, 10)
# 	G	(10, 11)
# 	R	(11, 12)
# 	.	(12, 13)
# 80
#
# Expression Input: S[IVLMH]E[IVPFMLYAQR]GR.
# Sequence Input: NDDDDNSVEQGRRLGESIMS
# Subequence Match: SVEQGRR
#
# 	S	(6, 7)
# 	[IVLMH]	(7, 8)
# 	E	(8, 9)
# 	[IVPFMLYAQR]	(9, 10)
# 	G	(10, 11)
# 	R	(11, 12)
# 	.	(12, 13)
# 81
#
# Expression Input: E[IMPVL][MLVP]R.
# Sequence Input: DQARPGPEIMRTIPEEELTD
# Subequence Match: EIMRT
#
# 	E	(7, 8)
# 	[IMPVL]	(8, 9)
# 	[MLVP]	(9, 10)
# 	R	(10, 11)
# 	.	(11, 12)
# 82
#
# Expression Input: E[IMPVL][MLVP]R.
# Sequence Input: NWRKMSFEILRGSDGEDSAS
# Subequence Match: EILRG
#
# 	E	(7, 8)
# 	[IMPVL]	(8, 9)
# 	[MLVP]	(9, 10)
# 	R	(10, 11)
# 	.	(11, 12)
# 83
#
# Expression Input: E[IMPVL][MLVP]R.
# Sequence Input: EAASGEWELLRLDSSKKKLP
# Subequence Match: ELLRL
#
# 	E	(7, 8)
# 	[IMPVL]	(8, 9)
# 	[MLVP]	(9, 10)
# 	R	(10, 11)
# 	.	(11, 12)
# 84
#
# Expression Input: E[IMPVL][MLVP]R.
# Sequence Input: LSSWSSPEVLRKDWTLEPWP
# Subequence Match: EVLRK
#
# 	E	(7, 8)
# 	[IMPVL]	(8, 9)
# 	[MLVP]	(9, 10)
# 	R	(10, 11)
# 	.	(11, 12)
# 85
#
# Expression Input: E[IMPVL][MLVP]R.
# Sequence Input: DFGMDDREIMREGSAFEDDD
# Subequence Match: EIMRE
#
# 	E	(7, 8)
# 	[IMPVL]	(8, 9)
# 	[MLVP]	(9, 10)
# 	R	(10, 11)
# 	.	(11, 12)
# 86
#
# Expression Input: Q[MLVI]DG..[DE]
# Sequence Input: KRSAEGQVDGADDLSTSDED
# Subequence Match: QVDGADD
#
# 	Q	(6, 7)
# 	[MLVI]	(7, 8)
# 	D	(8, 9)
# 	G	(9, 10)
# 	.	(10, 11)
# 	.	(11, 12)
# 	[DE]	(12, 13)
# 87
#
# Expression Input: Q[MLVI]DG..[DE]
# Sequence Input: DLPKISQLDGVDDGTESDTS
# Subequence Match: QLDGVDD
#
# 	Q	(6, 7)
# 	[MLVI]	(7, 8)
# 	D	(8, 9)
# 	G	(9, 10)
# 	.	(10, 11)
# 	.	(11, 12)
# 	[DE]	(12, 13)
# 88
#
# Expression Input: .R..L..[LIVM].
# Sequence Input: RHNPSERLPLAQVSAHPWVR
# Subequence Match: ERLPLAQVS
#
# 	.	(5, 6)
# 	R	(6, 7)
# 	.	(7, 8)
# 	.	(8, 9)
# 	L	(9, 10)
# 	.	(10, 11)
# 	.	(11, 12)
# 	[LIVM]	(12, 13)
# 	.	(13, 14)
# 89
#
# Expression Input: .R..L..[LIVM].
# Sequence Input: QPNLPQRTVLGVIGDNEQRR
# Subequence Match: QRTVLGVIG
#
# 	.	(5, 6)
# 	R	(6, 7)
# 	.	(7, 8)
# 	.	(8, 9)
# 	L	(9, 10)
# 	.	(10, 11)
# 	.	(11, 12)
# 	[LIVM]	(12, 13)
# 	.	(13, 14)
# 90
#
# Expression Input: .R..L..[LIVM].
# Sequence Input: KPGLRPRTALGDIGNKVSEQ
# Subequence Match: PRTALGDIG
#
# 	.	(5, 6)
# 	R	(6, 7)
# 	.	(7, 8)
# 	.	(8, 9)
# 	L	(9, 10)
# 	.	(10, 11)
# 	.	(11, 12)
# 	[LIVM]	(12, 13)
# 	.	(13, 14)
# 91
#
# Expression Input: .R..L..[LIVM].
# Sequence Input: VQKPAQRAALGNISNVVRTA
# Subequence Match: QRAALGNIS
#
# 	.	(5, 6)
# 	R	(6, 7)
# 	.	(7, 8)
# 	.	(8, 9)
# 	L	(9, 10)
# 	.	(10, 11)
# 	.	(11, 12)
# 	[LIVM]	(12, 13)
# 	.	(13, 14)
# 92
#
# Expression Input: .R..L..[LIVM].
# Sequence Input: GQNQASRTPLTTLNTDISIL
# Subequence Match: SRTPLTTLN
#
# 	.	(5, 6)
# 	R	(6, 7)
# 	.	(7, 8)
# 	.	(8, 9)
# 	L	(9, 10)
# 	.	(10, 11)
# 	.	(11, 12)
# 	[LIVM]	(12, 13)
# 	.	(13, 14)
# 93
#
# Expression Input: .R..L..[LIVM].
# Sequence Input: NEALAPRRTLKVIQQSASGC
# Subequence Match: PRRTLKVIQ
#
# 	.	(5, 6)
# 	R	(6, 7)
# 	.	(7, 8)
# 	.	(8, 9)
# 	L	(9, 10)
# 	.	(10, 11)
# 	.	(11, 12)
# 	[LIVM]	(12, 13)
# 	.	(13, 14)
# 94
#
# Expression Input: .R..L..[LIVM].
# Sequence Input: SLDPSNRKPLTVLNKGLENP
# Subequence Match: NRKPLTVLN
#
# 	.	(5, 6)
# 	R	(6, 7)
# 	.	(7, 8)
# 	.	(8, 9)
# 	L	(9, 10)
# 	.	(10, 11)
# 	.	(11, 12)
# 	[LIVM]	(12, 13)
# 	.	(13, 14)
# 95
#
# Expression Input: .R..L..[LIVM].
# Sequence Input: MVSKPSRKALGNVNKQILPK
# Subequence Match: SRKALGNVN
#
# 	.	(5, 6)
# 	R	(6, 7)
# 	.	(7, 8)
# 	.	(8, 9)
# 	L	(9, 10)
# 	.	(10, 11)
# 	.	(11, 12)
# 	[LIVM]	(12, 13)
# 	.	(13, 14)
# 96
#
# Expression Input: .R..L..[LIVM].
# Sequence Input: MHRKHLQEIPDLSSNVATSF
# Subequence Match: HRKHLQEIP
#
# 	.	(1, 2)
# 	R	(2, 3)
# 	.	(3, 4)
# 	.	(4, 5)
# 	L	(5, 6)
# 	.	(6, 7)
# 	.	(7, 8)
# 	[LIVM]	(8, 9)
# 	.	(9, 10)
# 97
#
# Expression Input: .R..L..[LIVM].
# Sequence Input: KHNPNHRLPLKGVLEHPWII
# Subequence Match: HRLPLKGVL
#
# 	.	(5, 6)
# 	R	(6, 7)
# 	.	(7, 8)
# 	.	(8, 9)
# 	L	(9, 10)
# 	.	(10, 11)
# 	.	(11, 12)
# 	[LIVM]	(12, 13)
# 	.	(13, 14)
# 98
#
# Expression Input: .R..L..[LIVM].
# Sequence Input: KHNPSQRPMLREVLEHPWIT
# Subequence Match: QRPMLREVL
#
# 	.	(5, 6)
# 	R	(6, 7)
# 	.	(7, 8)
# 	.	(8, 9)
# 	L	(9, 10)
# 	.	(10, 11)
# 	.	(11, 12)
# 	[LIVM]	(12, 13)
# 	.	(13, 14)
# 99
#
# Expression Input: .KEN.
# Sequence Input: NENNPSQVKENLSPAKICPY
# Subequence Match: VKENL
#
# 	.	(7, 8)
# 	K	(8, 9)
# 	E	(9, 10)
# 	N	(10, 11)
# 	.	(11, 12)
# 100
#
# Expression Input: .KEN.
# Sequence Input: MAQKENSYPWPYGRQTAPSG
# Subequence Match: QKENS
#
# 	.	(2, 3)
# 	K	(3, 4)
# 	E	(4, 5)
# 	N	(5, 6)
# 	.	(6, 7)
# 101
#
# Expression Input: .KEN.
# Sequence Input: EGDEWELSKENVQPLRQGRI
# Subequence Match: SKENV
#
# 	.	(7, 8)
# 	K	(8, 9)
# 	E	(9, 10)
# 	N	(10, 11)
# 	.	(11, 12)
# 102
#
# Expression Input: .KEN.
# Sequence Input: IAPPMPRAKENELQAGPWNT
# Subequence Match: AKENE
#
# 	.	(7, 8)
# 	K	(8, 9)
# 	E	(9, 10)
# 	N	(10, 11)
# 	.	(11, 12)
# 103
#
# Expression Input: .KEN.
# Sequence Input: FHVFEDGNKENYGLPQPKNK
# Subequence Match: NKENY
#
# 	.	(7, 8)
# 	K	(8, 9)
# 	E	(9, 10)
# 	N	(10, 11)
# 	.	(11, 12)
# 104
#
# Expression Input: .KEN.
# Sequence Input: ESVHILEDKENVVAKQCTQA
# Subequence Match: DKENV
#
# 	.	(7, 8)
# 	K	(8, 9)
# 	E	(9, 10)
# 	N	(10, 11)
# 	.	(11, 12)
# 105
#
# Expression Input: .KEN.
# Sequence Input: EVASFLLSKENQPENSQTPT
# Subequence Match: SKENQ
#
# 	.	(7, 8)
# 	K	(8, 9)
# 	E	(9, 10)
# 	N	(10, 11)
# 	.	(11, 12)
# 106
#
# Expression Input: .KEN.
# Sequence Input: CSPPKQGKKENGPPHSHTLK
# Subequence Match: KKENG
#
# 	.	(7, 8)
# 	K	(8, 9)
# 	E	(9, 10)
# 	N	(10, 11)
# 	.	(11, 12)
# 107
#
# Expression Input: .KEN.
# Sequence Input: PRISFFLEKENEPPGRELTK
# Subequence Match: EKENE
#
# 	.	(7, 8)
# 	K	(8, 9)
# 	E	(9, 10)
# 	N	(10, 11)
# 	.	(11, 12)
# 108
#
# Expression Input: .KEN.
# Sequence Input: PKNNLLDDKENQDPSSQQFG
# Subequence Match: DKENQ
#
# 	.	(7, 8)
# 	K	(8, 9)
# 	E	(9, 10)
# 	N	(10, 11)
# 	.	(11, 12)
# 109
#
# Expression Input: .KEN.
# Sequence Input: NIMKNYGNKENATKDEMIEN
# Subequence Match: NKENA
#
# 	.	(7, 8)
# 	K	(8, 9)
# 	E	(9, 10)
# 	N	(10, 11)
# 	.	(11, 12)
# 110
#
# Expression Input: .KEN.
# Sequence Input: KLKTKMADKENMKRPAESKN
# Subequence Match: DKENM
#
# 	.	(7, 8)
# 	K	(8, 9)
# 	E	(9, 10)
# 	N	(10, 11)
# 	.	(11, 12)
# 111
#
# Expression Input: .KEN.
# Sequence Input: TISGVSTNKENEGPEYPTKI
# Subequence Match: NKENE
#
# 	.	(7, 8)
# 	K	(8, 9)
# 	E	(9, 10)
# 	N	(10, 11)
# 	.	(11, 12)
# 112
#
# Expression Input: .KEN.
# Sequence Input: AMCSSSANKENDNGNLVDSE
# Subequence Match: NKEND
#
# 	.	(7, 8)
# 	K	(8, 9)
# 	E	(9, 10)
# 	N	(10, 11)
# 	.	(11, 12)
# 113
#
# Expression Input: .KEN.
# Sequence Input: MATLIYVDKENGEPGTRVVA
# Subequence Match: DKENG
#
# 	.	(7, 8)
# 	K	(8, 9)
# 	E	(9, 10)
# 	N	(10, 11)
# 	.	(11, 12)
# 114
#
# Expression Input: .KEN.
# Sequence Input: TEAECESDKENEEPGAGVEL
# Subequence Match: DKENE
#
# 	.	(7, 8)
# 	K	(8, 9)
# 	E	(9, 10)
# 	N	(10, 11)
# 	.	(11, 12)
# 115
#
# Expression Input: .[ILM]R$
# Sequence Input: GSNIIEYMEGIETTHNKRIR
# Subequence Match: RIR
#
# 	.	(17, 18)
# 	[ILM]	(18, 19)
# 	R$	(19, 20)
# 116
#
# Expression Input: .[ILM]R$
# Sequence Input: SIGKFPRCTTIDFMMYRSIR
# Subequence Match: SIR
#
# 	.	(17, 18)
# 	[ILM]	(18, 19)
# 	R$	(19, 20)
# 117
#
# Expression Input: .[ILM]R$
# Sequence Input: RREREKASAAKSSLIHQGIR
# Subequence Match: GIR
#
# 	.	(17, 18)
# 	[ILM]	(18, 19)
# 	R$	(19, 20)
# 118
#
# Expression Input: .[ILM]R$
# Sequence Input: KNSSEIHTRRPSSTSQYLIR
# Subequence Match: LIR
#
# 	.	(17, 18)
# 	[ILM]	(18, 19)
# 	R$	(19, 20)
# 119
#
# Expression Input: .[ILM]R$
# Sequence Input: KPKAKVQPNSLIFDAFNQIR
# Subequence Match: QIR
#
# 	.	(17, 18)
# 	[ILM]	(18, 19)
# 	R$	(19, 20)
# 120
#
# Expression Input: .[ILM]R$
# Sequence Input: KQEQKAKDKCSSLSLYKGIR
# Subequence Match: GIR
#
# 	.	(17, 18)
# 	[ILM]	(18, 19)
# 	R$	(19, 20)
# 121
#
# Expression Input: .[ILM]R$
# Sequence Input: KSQNTDSEIGSSFFGRTTIR
# Subequence Match: TIR
#
# 	.	(17, 18)
# 	[ILM]	(18, 19)
# 	R$	(19, 20)
# 122
#
# Expression Input: .[ILM]R$
# Sequence Input: KMQTPVKDTGLWSLGRTQIR
# Subequence Match: QIR
#
# 	.	(17, 18)
# 	[ILM]	(18, 19)
# 	R$	(19, 20)
# 123
#
# Expression Input: .[ILM]R$
# Sequence Input: RSTKVKWESVSVLNLFTRIR
# Subequence Match: RIR
#
# 	.	(17, 18)
# 	[ILM]	(18, 19)
# 	R$	(19, 20)
# 124
#
# Expression Input: .[ILM]R$
# Sequence Input: KINPSMVRKFGRNISKGNLR
# Subequence Match: NLR
#
# 	.	(17, 18)
# 	[ILM]	(18, 19)
# 	R$	(19, 20)
# 125
#
# Expression Input: .[ILM]R$
# Sequence Input: HSSHKQPSKARSPNPLLSMR
# Subequence Match: SMR
#
# 	.	(17, 18)
# 	[ILM]	(18, 19)
# 	R$	(19, 20)
# 126
#
# Expression Input: .[ILM]R$
# Sequence Input: TLRFWKLFNKKPKEESTLIR
# Subequence Match: LIR
#
# 	.	(17, 18)
# 	[ILM]	(18, 19)
# 	R$	(19, 20)
# 127
#
# Expression Input: .[ILM]R$
# Sequence Input: ALSDIEKNYQLKSRQILGMR
# Subequence Match: GMR
#
# 	.	(17, 18)
# 	[ILM]	(18, 19)
# 	R$	(19, 20)
# 128
#
# Expression Input: .[ILM]R$
# Sequence Input: TKKAASKKYTDPFAHVNHIR
# Subequence Match: HIR
#
# 	.	(17, 18)
# 	[ILM]	(18, 19)
# 	R$	(19, 20)
# 129
#
# Expression Input: .[ILM]R$
# Sequence Input: KTPAPVKDTGLWSLGRTQIR
# Subequence Match: QIR
#
# 	.	(17, 18)
# 	[ILM]	(18, 19)
# 	R$	(19, 20)
# 130
#
# Expression Input: .[ILM]R$
# Sequence Input: TPQAKREEREKRVRTLMTMR
# Subequence Match: TMR
#
# 	.	(17, 18)
# 	[ILM]	(18, 19)
# 	R$	(19, 20)
# 131
#
# Expression Input: .[ILM]R$
# Sequence Input: KSQNTESEIGALSLGRTTIR
# Subequence Match: TIR
#
# 	.	(17, 18)
# 	[ILM]	(18, 19)
# 	R$	(19, 20)
# 132
#
# Expression Input: .[ILM]R$
# Sequence Input: AKKAAPKAVAEPFSHVNRIR
# Subequence Match: RIR
#
# 	.	(17, 18)
# 	[ILM]	(18, 19)
# 	R$	(19, 20)
# 133
#
# Expression Input: .[ILM]R$
# Sequence Input: AKKAAPKAVSEPFSHVNRIR
# Subequence Match: RIR
#
# 	.	(17, 18)
# 	[ILM]	(18, 19)
# 	R$	(19, 20)
# 134
#
# Expression Input: .[ILM]R$
# Sequence Input: TKQKISKEPNSVLRLFKGIR
# Subequence Match: GIR
#
# 	.	(17, 18)
# 	[ILM]	(18, 19)
# 	R$	(19, 20)
# 135
#
# Expression Input: .[ILM]R$
# Sequence Input: DHVKRPIPITKTPSSSITIR
# Subequence Match: TIR
#
# 	.	(17, 18)
# 	[ILM]	(18, 19)
# 	R$	(19, 20)
# 136
#
# Expression Input: .[ILM]R$
# Sequence Input: KSKHSASTMSSPFDPTMKIR
# Subequence Match: KIR
#
# 	.	(17, 18)
# 	[ILM]	(18, 19)
# 	R$	(19, 20)
# 137
#
# Expression Input: [STDE]{1,3}.{0,2}[TSDE].{2,3}VP[STDE]G{0,1}[FLIMVYPA]
# Sequence Input: SSQSSFNSLQRVPSYDSFDS
# Subequence Match: SSFNSLQRVPSY
#
# 	[STDE]{2}	(3, 5)
# 	.{2}	(5, 7)
# 	[TSDE]	(7, 8)
# 	.{3}	(8, 11)
# 	V	(11, 12)
# 	P	(12, 13)
# 	[STDE]	(13, 14)
# 	G{0}	(14, 14)
# 	[FLIMVYPA]	(14, 15)
# 138
#
# Expression Input: [STDE]{1,3}.{0,2}[TSDE].{2,3}VP[STDE]G{0,1}[FLIMVYPA]
# Sequence Input: SLNEEQTLQEVPTGLDSISH
# Subequence Match: EEQTLQEVPTGL
#
# 	[STDE]{2}	(3, 5)
# 	.{1}	(5, 6)
# 	[TSDE]	(6, 7)
# 	.{3}	(7, 10)
# 	V	(10, 11)
# 	P	(11, 12)
# 	[STDE]	(12, 13)
# 	G{1}	(13, 14)
# 	[FLIMVYPA]	(14, 15)
# 139
#
# Expression Input: [STDE]{1,3}.{0,2}[TSDE].{2,3}VP[STDE]G{0,1}[FLIMVYPA]
# Sequence Input: NSQSSLLDVQRVPSFESFED
# Subequence Match: SSLLDVQRVPSF
#
# 	[STDE]{2}	(3, 5)
# 	.{2}	(5, 7)
# 	[TSDE]	(7, 8)
# 	.{3}	(8, 11)
# 	V	(11, 12)
# 	P	(12, 13)
# 	[STDE]	(13, 14)
# 	G{0}	(14, 14)
# 	[FLIMVYPA]	(14, 15)
# 140
#
# Expression Input: [STDE]{1,3}.{0,2}[TSDE].{2,3}VP[STDE]G{0,1}[FLIMVYPA]
# Sequence Input: AQVPDNDEQFVPDYQAESLA
# Subequence Match: DNDEQFVPDY
#
# 	[STDE]{1}	(4, 5)
# 	.{2}	(5, 7)
# 	[TSDE]	(7, 8)
# 	.{2}	(8, 10)
# 	V	(10, 11)
# 	P	(11, 12)
# 	[STDE]	(12, 13)
# 	G{0}	(13, 13)
# 	[FLIMVYPA]	(13, 14)
# 141
#
# Expression Input: [STDE]{1,3}.{0,2}[TSDE].{2,3}VP[STDE]G{0,1}[FLIMVYPA]
# Sequence Input: AQVPDSDEQFVPDFHSENLA
# Subequence Match: DSDEQFVPDF
#
# 	[STDE]{3}	(4, 7)
# 	.{0}	(7, 7)
# 	[TSDE]	(7, 8)
# 	.{2}	(8, 10)
# 	V	(10, 11)
# 	P	(11, 12)
# 	[STDE]	(12, 13)
# 	G{0}	(13, 13)
# 	[FLIMVYPA]	(13, 14)
# 142
#
# Expression Input: [STDE]{1,3}.{0,2}[TSDE].{2,3}VP[STDE]G{0,1}[FLIMVYPA]
# Sequence Input: EAQVPDDEQFVPDFQSDNLV
# Subequence Match: DDEQFVPDF
#
# 	[STDE]{2}	(5, 7)
# 	.{0}	(7, 7)
# 	[TSDE]	(7, 8)
# 	.{2}	(8, 10)
# 	V	(10, 11)
# 	P	(11, 12)
# 	[STDE]	(12, 13)
# 	G{0}	(13, 13)
# 	[FLIMVYPA]	(13, 14)
# 143
#
# Expression Input: [STDE]{1,3}.{0,2}[TSDE].{2,3}VP[STDE]G{0,1}[FLIMVYPA]
# Sequence Input: GIESDEEIRRVPEFGGEAVG
# Subequence Match: ESDEEIRRVPEF
#
# 	[STDE]{3}	(2, 5)
# 	.{1}	(5, 6)
# 	[TSDE]	(6, 7)
# 	.{3}	(7, 10)
# 	V	(10, 11)
# 	P	(11, 12)
# 	[STDE]	(12, 13)
# 	G{0}	(13, 13)
# 	[FLIMVYPA]	(13, 14)
# 144
#
# Expression Input: [STDE]{1,3}.{0,2}[TSDE].{2,3}VP[STDE]G{0,1}[FLIMVYPA]
# Sequence Input: TEESDEELLMVPDMEAAGST
# Subequence Match: EESDEELLMVPDM
#
# 	[STDE]{3}	(1, 4)
# 	.{2}	(4, 6)
# 	[TSDE]	(6, 7)
# 	.{3}	(7, 10)
# 	V	(10, 11)
# 	P	(11, 12)
# 	[STDE]	(12, 13)
# 	G{0}	(13, 13)
# 	[FLIMVYPA]	(13, 14)
# 145
#
# Expression Input: [STDE]{1,3}.{0,2}[TSDE].{2,3}VP[STDE]G{0,1}[FLIMVYPA]
# Sequence Input: ALKDEPQTVPDVPSFGESPP
# Subequence Match: DEPQTVPDVPSF
#
# 	[STDE]{2}	(3, 5)
# 	.{2}	(5, 7)
# 	[TSDE]	(7, 8)
# 	.{3}	(8, 11)
# 	V	(11, 12)
# 	P	(12, 13)
# 	[STDE]	(13, 14)
# 	G{0}	(14, 14)
# 	[FLIMVYPA]	(14, 15)
# 146
#
# Expression Input: [STDE]{1,3}.{0,2}[TSDE].{2,3}VP[STDE]G{0,1}[FLIMVYPA]
# Sequence Input: LQALKEEPQTVPEMPGETPP
# Subequence Match: EEPQTVPEM
#
# 	[STDE]{2}	(5, 7)
# 	.{2}	(7, 9)
# 	[TSDE]	(9, 10)
# 	V	(10, 11)
# 	P	(11, 12)
# 	[STDE]	(12, 13)
# 	G{0}	(13, 13)
# 	G{0}	(13, 13)
# 	[FLIMVYPA]	(13, 14)
# 147
#
# Expression Input: [STDE]{1,3}.{0,2}[TSDE].{2,3}VP[STDE]G{0,1}[FLIMVYPA]
# Sequence Input: QRLEYRYDDEEEHFLVPDLG
# Subequence Match: DDEEEHFLVPDL
#
# 	[STDE]{3}	(7, 10)
# 	.{1}	(10, 11)
# 	[TSDE]	(11, 12)
# 	.{3}	(12, 15)
# 	V	(15, 16)
# 	P	(16, 17)
# 	[STDE]	(17, 18)
# 	G{0}	(18, 18)
# 	[FLIMVYPA]	(18, 19)
# 148
#
# Expression Input: [STDE]{1,3}.{0,2}[TSDE].{2,3}VP[STDE]G{0,1}[FLIMVYPA]
# Sequence Input: DSEIGTSDQIVPEYQEDSDI
# Subequence Match: TSDQIVPEY
#
# 	[STDE]{2}	(5, 7)
# 	.{0}	(7, 7)
# 	[TSDE]	(7, 8)
# 	.{2}	(8, 10)
# 	V	(10, 11)
# 	P	(11, 12)
# 	[STDE]	(12, 13)
# 	G{0}	(13, 13)
# 	[FLIMVYPA]	(13, 14)
# 149
#
# Expression Input: [NQ]{0,1}..[ILMV][ST][DEN][FY][FY].{2,3}[KR]{2,3}[^DE]
# Sequence Input: RRQTSMTDFYHSKRRLIFSK
# Subequence Match: QTSMTDFYHSKRRL
#
# 	[NQ]{1}	(2, 3)
# 	.	(3, 4)
# 	.	(4, 5)
# 	[ILMV]	(5, 6)
# 	[ST]	(6, 7)
# 	[DEN]	(7, 8)
# 	[FY]	(8, 9)
# 	[FY]	(9, 10)
# 	.{3}	(10, 13)
# 	[KR]{2}	(13, 15)
# 	[^DE]	(15, 16)
# 150
#
# Expression Input: [NQ]{0,1}..[ILMV][ST][DEN][FY][FY].{2,3}[KR]{2,3}[^DE]
# Sequence Input: LSGPLISDFFAKRKRSAPEK
# Subequence Match: PLISDFFAKRKRS
#
# 	[NQ]{0}	(3, 3)
# 	.	(3, 4)
# 	.	(4, 5)
# 	[ILMV]	(5, 6)
# 	[ST]	(6, 7)
# 	[DEN]	(7, 8)
# 	[FY]	(8, 9)
# 	[FY]	(9, 10)
# 	.{3}	(10, 13)
# 	[KR]{2}	(13, 15)
# 	[^DE]	(15, 16)
# 151
#
# Expression Input: [NQ]{0,1}..[ILMV][ST][DEN][FY][FY].{2,3}[KR]{2,3}[^DE]
# Sequence Input: MEQRRVTDFFARRRPGPPRI
# Subequence Match: QRRVTDFFARRRP
#
# 	[NQ]{1}	(2, 3)
# 	.	(3, 4)
# 	.	(4, 5)
# 	[ILMV]	(5, 6)
# 	[ST]	(6, 7)
# 	[DEN]	(7, 8)
# 	[FY]	(8, 9)
# 	[FY]	(9, 10)
# 	.{2}	(10, 12)
# 	[KR]{2}	(12, 14)
# 	[^DE]	(14, 15)
# 152
#
# Expression Input: [NQ]{0,1}..[ILMV][ST][DEN][FY][FY].{2,3}[KR]{2,3}[^DE]
# Sequence Input: MSQMRVTDFFSQSKRGTAAQ
# Subequence Match: QMRVTDFFSQSKRG
#
# 	[NQ]{1}	(2, 3)
# 	.	(3, 4)
# 	.	(4, 5)
# 	[ILMV]	(5, 6)
# 	[ST]	(6, 7)
# 	[DEN]	(7, 8)
# 	[FY]	(8, 9)
# 	[FY]	(9, 10)
# 	.{3}	(10, 13)
# 	[KR]{2}	(13, 15)
# 	[^DE]	(15, 16)
# 153
#
# Expression Input: [NQ]{0,1}..[ILMV][ST][DEN][FY][FY].{2,3}[KR]{2,3}[^DE]
# Sequence Input: EITTPITDYFPKRKKILSAK
# Subequence Match: TPITDYFPKRKKI
#
# 	[NQ]{0}	(3, 3)
# 	.	(3, 4)
# 	.	(4, 5)
# 	[ILMV]	(5, 6)
# 	[ST]	(6, 7)
# 	[DEN]	(7, 8)
# 	[FY]	(8, 9)
# 	[FY]	(9, 10)
# 	.{3}	(10, 13)
# 	[KR]{2}	(13, 15)
# 	[^DE]	(15, 16)
# 154
#
# Expression Input: [NQ]{0,1}..[ILMV][ST][DEN][FY][FY].{2,3}[KR]{2,3}[^DE]
# Sequence Input: TQQNRKLTDFYPVRRSSRKS
# Subequence Match: NRKLTDFYPVRRS
#
# 	[NQ]{1}	(3, 4)
# 	.	(4, 5)
# 	.	(5, 6)
# 	[ILMV]	(6, 7)
# 	[ST]	(7, 8)
# 	[DEN]	(8, 9)
# 	[FY]	(9, 10)
# 	[FY]	(10, 11)
# 	.{2}	(11, 13)
# 	[KR]{2}	(13, 15)
# 	[^DE]	(15, 16)
# 155
#
# Expression Input: [NQ]{0,1}..[ILMV]T[DEN][HMFY][FMY].{2,3}[KR]{2,3}[^DE]
# Sequence Input: GKSNDITNYYKVKRRPHAVS
# Subequence Match: NDITNYYKVKRRP
#
# 	[NQ]{0}	(3, 3)
# 	.	(3, 4)
# 	.	(4, 5)
# 	[ILMV]	(5, 6)
# 	T	(6, 7)
# 	[DEN]	(7, 8)
# 	[HMFY]	(8, 9)
# 	[FMY]	(9, 10)
# 	.{3}	(10, 13)
# 	[KR]{2}	(13, 15)
# 	[^DE]	(15, 16)
# 156
#
# Expression Input: [AP]P[MV][IM]V
# Sequence Input: RLKHKPQAPVIVKTEEVINM
# Subequence Match: APVIV
#
# 	[AP]	(7, 8)
# 	P	(8, 9)
# 	[MV]	(9, 10)
# 	[IM]	(10, 11)
# 	V	(11, 12)
# 157
#
# Expression Input: [DNS].[DES][TNS]GE
# Sequence Input: SSLEEPHSPETGEKVVAGEV
# Subequence Match: SPETGE
#
# 	[DNS]	(7, 8)
# 	.	(8, 9)
# 	[DES]	(9, 10)
# 	[TNS]	(10, 11)
# 	G	(11, 12)
# 	E	(12, 13)
# 158
#
# Expression Input: [DNS].[DES][TNS]GE
# Sequence Input: ESAKAADDPENGERESHTPV
# Subequence Match: DPENGE
#
# 	[DNS]	(7, 8)
# 	.	(8, 9)
# 	[DES]	(9, 10)
# 	[TNS]	(10, 11)
# 	G	(11, 12)
# 	E	(12, 13)
# 159
#
# Expression Input: [DNS].[DES][TNS]GE
# Sequence Input: NGIPFTIDNETGEYIRLPLD
# Subequence Match: DNETGE
#
# 	[DNS]	(7, 8)
# 	.	(8, 9)
# 	[DES]	(9, 10)
# 	[TNS]	(10, 11)
# 	G	(11, 12)
# 	E	(12, 13)
# 160
#
# Expression Input: [DNS].[DES][TNS]GE
# Sequence Input: GNVIRWHNQETGEQIAIKQC
# Subequence Match: NQETGE
#
# 	[DNS]	(7, 8)
# 	.	(8, 9)
# 	[DES]	(9, 10)
# 	[TNS]	(10, 11)
# 	G	(11, 12)
# 	E	(12, 13)
# 161
#
# Expression Input: [DNS].[DES][TNS]GE
# Sequence Input: KGDLIILDHDTGEQVMNSGW
# Subequence Match: DHDTGE
#
# 	[DNS]	(7, 8)
# 	.	(8, 9)
# 	[DES]	(9, 10)
# 	[TNS]	(10, 11)
# 	G	(11, 12)
# 	E	(12, 13)
# 162
#
# Expression Input: [DNS].[DES][TNS]GE
# Sequence Input: LARNLLVDGETGESFPAQVP
# Subequence Match: DGETGE
#
# 	[DNS]	(7, 8)
# 	.	(8, 9)
# 	[DES]	(9, 10)
# 	[TNS]	(10, 11)
# 	G	(11, 12)
# 	E	(12, 13)
# 163
#
# Expression Input: [DNS].[DES][TNS]GE
# Sequence Input: FFAQLQLDEETGEFLPIQPA
# Subequence Match: DEETGE
#
# 	[DNS]	(7, 8)
# 	.	(8, 9)
# 	[DES]	(9, 10)
# 	[TNS]	(10, 11)
# 	G	(11, 12)
# 	E	(12, 13)
# 164
#
# Expression Input: [DNS].[DES][TNS]GE
# Sequence Input: FFAQFQLDEETGEFLPIQPA
# Subequence Match: DEETGE
#
# 	[DNS]	(7, 8)
# 	.	(8, 9)
# 	[DES]	(9, 10)
# 	[TNS]	(10, 11)
# 	G	(11, 12)
# 	E	(12, 13)
# 165
#
# Expression Input: [DNS].[DES][TNS]GE
# Sequence Input: LHIKTHLDEETGEKTSITLD
# Subequence Match: DEETGE
#
# 	[DNS]	(7, 8)
# 	.	(8, 9)
# 	[DES]	(9, 10)
# 	[TNS]	(10, 11)
# 	G	(11, 12)
# 	E	(12, 13)
# 166
#
# Expression Input: [DNS].[DES][TNS]GE
# Sequence Input: LINVRKRNVESGEEELASKL
# Subequence Match: NVESGE
#
# 	[DNS]	(7, 8)
# 	.	(8, 9)
# 	[DES]	(9, 10)
# 	[TNS]	(10, 11)
# 	G	(11, 12)
# 	E	(12, 13)
# 167
#
# Expression Input: [DNS].[DES][TNS]GE
# Sequence Input: PANGNAQNEENGEQEADNEV
# Subequence Match: NEENGE
#
# 	[DNS]	(7, 8)
# 	.	(8, 9)
# 	[DES]	(9, 10)
# 	[TNS]	(10, 11)
# 	G	(11, 12)
# 	E	(12, 13)
# 168
#
# Expression Input: [DNS].[DES][TNS]GE
# Sequence Input: HLSSKEVDPSTGELQSLQMP
# Subequence Match: DPSTGE
#
# 	[DNS]	(7, 8)
# 	.	(8, 9)
# 	[DES]	(9, 10)
# 	[TNS]	(10, 11)
# 	G	(11, 12)
# 	E	(12, 13)
# 169
#
# Expression Input: [DNS].[DES][TNS]GE
# Sequence Input: HLSSKEVDPSTGELQSLQMP
# Subequence Match: DPSTGE
#
# 	[DNS]	(7, 8)
# 	.	(8, 9)
# 	[DES]	(9, 10)
# 	[TNS]	(10, 11)
# 	G	(11, 12)
# 	E	(12, 13)
# 170
#
# Expression Input: QD.DLGV
# Sequence Input: IDILWRQDIDLGVSREVFDF
# Subequence Match: QDIDLGV
#
# 	Q	(6, 7)
# 	D	(7, 8)
# 	.	(8, 9)
# 	D	(9, 10)
# 	L	(10, 11)
# 	G	(11, 12)
# 	V	(12, 13)
# 171
#
# Expression Input: E.EE.E[AV]DQH
# Sequence Input: VSTQVEPEEPEADQHQQLQY
# Subequence Match: EPEEPEADQH
#
# 	E	(5, 6)
# 	.	(6, 7)
# 	E	(7, 8)
# 	E	(8, 9)
# 	.	(9, 10)
# 	E	(10, 11)
# 	[AV]	(11, 12)
# 	D	(12, 13)
# 	Q	(13, 14)
# 	H	(14, 15)
# 172
#
# Expression Input: E.EE.E[AV]DQH
# Sequence Input: QPGPPEPEEPEADQHLLPPT
# Subequence Match: EPEEPEADQH
#
# 	E	(5, 6)
# 	.	(6, 7)
# 	E	(7, 8)
# 	E	(8, 9)
# 	.	(9, 10)
# 	E	(10, 11)
# 	[AV]	(11, 12)
# 	D	(12, 13)
# 	Q	(13, 14)
# 	H	(14, 15)
# 173
#
# Expression Input: E.EE.E[AV]DQH
# Sequence Input: QQTGAECEETEVDQHVRQQL
# Subequence Match: ECEETEVDQH
#
# 	E	(5, 6)
# 	.	(6, 7)
# 	E	(7, 8)
# 	E	(8, 9)
# 	.	(9, 10)
# 	E	(10, 11)
# 	[AV]	(11, 12)
# 	D	(12, 13)
# 	Q	(13, 14)
# 	H	(14, 15)
# 174
#
# Expression Input: E.EE.E[AV]DQH
# Sequence Input: SVFPPEPEEPEADQHQPFLF
# Subequence Match: EPEEPEADQH
#
# 	E	(5, 6)
# 	.	(6, 7)
# 	E	(7, 8)
# 	E	(8, 9)
# 	.	(9, 10)
# 	E	(10, 11)
# 	[AV]	(11, 12)
# 	D	(12, 13)
# 	Q	(13, 14)
# 	H	(14, 15)
# 175
#
# Expression Input: F[^P]{3}W[^P]{2,3}[VIL]
# Sequence Input: TCPVDPFEAQWAALENKSKQ
# Subequence Match: FEAQWAAL
#
# 	F	(6, 7)
# 	[^P]{3}	(7, 10)
# 	W	(10, 11)
# 	[^P]{2}	(11, 13)
# 	[VIL]	(13, 14)
# 176
#
# Expression Input: F[^P]{3}W[^P]{2,3}[VIL]
# Sequence Input: APELDPFEAQWAALEGKATV
# Subequence Match: FEAQWAAL
#
# 	F	(6, 7)
# 	[^P]{3}	(7, 10)
# 	W	(10, 11)
# 	[^P]{2}	(11, 13)
# 	[VIL]	(13, 14)
# 177
#
# Expression Input: F[^P]{3}W[^P]{2,3}[VIL]
# Sequence Input: PLSQETFSDLWKLLPENNVL
# Subequence Match: FSDLWKLL
#
# 	F	(6, 7)
# 	[^P]{3}	(7, 10)
# 	W	(10, 11)
# 	[^P]{2}	(11, 13)
# 	[VIL]	(13, 14)
# 178
#
# Expression Input: F[^P]{3}W[^P]{2,3}[VIL]
# Sequence Input: FLSPEVFQHIWDFLEQPICS
# Subequence Match: FQHIWDFL
#
# 	F	(6, 7)
# 	[^P]{3}	(7, 10)
# 	W	(10, 11)
# 	[^P]{2}	(11, 13)
# 	[VIL]	(13, 14)
# 179
#
# Expression Input: F[^P]{3}W[^P]{2,3}[VIL]
# Sequence Input: PDGGTTFEHLWSSLEPDSTY
# Subequence Match: FEHLWSSL
#
# 	F	(6, 7)
# 	[^P]{3}	(7, 10)
# 	W	(10, 11)
# 	[^P]{2}	(11, 13)
# 	[VIL]	(13, 14)
# 180
#
# Expression Input: ^M{0,1}(C).
# Sequence Input: MCGGAIISDFIWSKSESEPS
# Subequence Match: MCG
#
# 	^M{1}	(0, 1)
# 	C	(1, 2)
# 	.	(2, 3)
# 181
#
# Expression Input: ^M{0,1}(C).
# Sequence Input: MCGGAVISDYIAPEKIARSS
# Subequence Match: MCG
#
# 	^M{1}	(0, 1)
# 	C	(1, 2)
# 	.	(2, 3)
# 182
#
# Expression Input: ^M{0,1}(C).
# Sequence Input: MCGGAIISDFIPPPRSRRVT
# Subequence Match: MCG
#
# 	^M{1}	(0, 1)
# 	C	(1, 2)
# 	.	(2, 3)
# 183
#
# Expression Input: ^M{0,1}(C).
# Sequence Input: MCGGAIISDFIPPPRSLRVT
# Subequence Match: MCG
#
# 	^M{1}	(0, 1)
# 	C	(1, 2)
# 	.	(2, 3)
# 184
#
# Expression Input: ^M{0,1}(C).
# Sequence Input: MCGGAIISDYAPLVTKAKGR
# Subequence Match: MCG
#
# 	^M{1}	(0, 1)
# 	C	(1, 2)
# 	.	(2, 3)
# 185
#
# Expression Input: ^M{0,1}(C).
# Sequence Input: MCRTLATFPNTCLERAKEFK
# Subequence Match: MCR
#
# 	^M{1}	(0, 1)
# 	C	(1, 2)
# 	.	(2, 3)
# 186
#
# Expression Input: ^M{0,1}(C).
# Sequence Input: MCKGLAGLPASCLRSAKDMK
# Subequence Match: MCK
#
# 	^M{1}	(0, 1)
# 	C	(1, 2)
# 	.	(2, 3)
# 187
#
# Expression Input: ^M{0,1}(C).
# Sequence Input: MCKGLAALPHSCLERAKEIK
# Subequence Match: MCK
#
# 	^M{1}	(0, 1)
# 	C	(1, 2)
# 	.	(2, 3)
# 188
#
# Expression Input: [IL]A(P).{6,8}[FLIVM].[FLIVM]
# Sequence Input: LAQLAPTPGDAIISLDFGNQ
# Subequence Match: LAPTPGDAIISLDF
#
# 	[IL]	(3, 4)
# 	A	(4, 5)
# 	P	(5, 6)
# 	.{8}	(6, 14)
# 	[FLIVM]	(14, 15)
# 	.	(15, 16)
# 	[FLIVM]	(16, 17)
# 189
#
# Expression Input: [IL]A(P).{6,8}[FLIVM].[FLIVM]
# Sequence Input: LETLAPYIPMDGEDFQLSPI
# Subequence Match: LAPYIPMDGEDFQL
#
# 	[IL]	(3, 4)
# 	A	(4, 5)
# 	P	(5, 6)
# 	.{8}	(6, 14)
# 	[FLIVM]	(14, 15)
# 	.	(15, 16)
# 	[FLIVM]	(16, 17)
# 190
#
# Expression Input: [IL]A(P).{6,8}[FLIVM].[FLIVM]
# Sequence Input: IFQPLAPVAPHSPFLLDKFQ
# Subequence Match: LAPVAPHSPFLL
#
# 	[IL]	(4, 5)
# 	A	(5, 6)
# 	P	(6, 7)
# 	.{6}	(7, 13)
# 	[FLIVM]	(13, 14)
# 	.	(14, 15)
# 	[FLIVM]	(15, 16)
# 191
#
# Expression Input: [IL]A(P).{6,8}[FLIVM].[FLIVM]
# Sequence Input: LTLLAPAAGDTIISLDFGSN
# Subequence Match: LAPAAGDTIISLDF
#
# 	[IL]	(3, 4)
# 	A	(4, 5)
# 	P	(5, 6)
# 	.{8}	(6, 14)
# 	[FLIVM]	(14, 15)
# 	.	(15, 16)
# 	[FLIVM]	(16, 17)
# 192
#
# Expression Input: [IL]A(P).{6,8}[FLIVM].[FLIVM]
# Sequence Input: LEMLAPYIPMDDDFQLRSFD
# Subequence Match: LAPYIPMDDDFQL
#
# 	[IL]	(3, 4)
# 	A	(4, 5)
# 	P	(5, 6)
# 	.{7}	(6, 13)
# 	[FLIVM]	(13, 14)
# 	.	(14, 15)
# 	[FLIVM]	(15, 16)
# 193
#
# Expression Input: [IL]A(P).{6,8}[FLIVM].[FLIVM]
# Sequence Input: LSCLAPFVDTYDMMQMDEGL
# Subequence Match: LAPFVDTYDMMQM
#
# 	[IL]	(3, 4)
# 	A	(4, 5)
# 	P	(5, 6)
# 	.{7}	(6, 13)
# 	[FLIVM]	(13, 14)
# 	.	(14, 15)
# 	[FLIVM]	(15, 16)
# 194
#
# Expression Input: [IL]A(P).{6,8}[FLIVM].[FLIVM]
# Sequence Input: LEMLAPYISMDDDFQLNASE
# Subequence Match: LAPYISMDDDFQL
#
# 	[IL]	(3, 4)
# 	A	(4, 5)
# 	P	(5, 6)
# 	.{7}	(6, 13)
# 	[FLIVM]	(13, 14)
# 	.	(14, 15)
# 	[FLIVM]	(15, 16)
# 195
#
# Expression Input: [IL]A(P).{6,8}[FLIVM].[FLIVM]
# Sequence Input: NGASIAPVNTKATIRLVESK
# Subequence Match: IAPVNTKATIRL
#
# 	[IL]	(4, 5)
# 	A	(5, 6)
# 	P	(6, 7)
# 	.{6}	(7, 13)
# 	[FLIVM]	(13, 14)
# 	.	(14, 15)
# 	[FLIVM]	(15, 16)
# 196
#
# Expression Input: ..[RK][RK].SL..F[FLM].[RK]R[HRK].[RK].
# Sequence Input: PIARRNSLTRFLEKRKDRVT
# Subequence Match: IARRNSLTRFLEKRKDRV
#
# 	.	(1, 2)
# 	.	(2, 3)
# 	[RK]	(3, 4)
# 	[RK]	(4, 5)
# 	.	(5, 6)
# 	S	(6, 7)
# 	L	(7, 8)
# 	.	(8, 9)
# 	.	(9, 10)
# 	F	(10, 11)
# 	[FLM]	(11, 12)
# 	.	(12, 13)
# 	[RK]	(13, 14)
# 	R	(14, 15)
# 	[HRK]	(15, 16)
# 	.	(16, 17)
# 	[RK]	(17, 18)
# 	.	(18, 19)
# 197
#
# Expression Input: ..[RK][RK].SL..F[FLM].[RK]R[HRK].[RK].
# Sequence Input: PQARKASLARFLEKRKERVM
# Subequence Match: QARKASLARFLEKRKERV
#
# 	.	(1, 2)
# 	.	(2, 3)
# 	[RK]	(3, 4)
# 	[RK]	(4, 5)
# 	.	(5, 6)
# 	S	(6, 7)
# 	L	(7, 8)
# 	.	(8, 9)
# 	.	(9, 10)
# 	F	(10, 11)
# 	[FLM]	(11, 12)
# 	.	(12, 13)
# 	[RK]	(13, 14)
# 	R	(14, 15)
# 	[HRK]	(15, 16)
# 	.	(16, 17)
# 	[RK]	(17, 18)
# 	.	(18, 19)
# 198
#
# Expression Input: ..[RK][RK].SL..F[FLM].[RK]R[HRK].[RK].
# Sequence Input: PIARRASLHRFLEKRKDRVT
# Subequence Match: IARRASLHRFLEKRKDRV
#
# 	.	(1, 2)
# 	.	(2, 3)
# 	[RK]	(3, 4)
# 	[RK]	(4, 5)
# 	.	(5, 6)
# 	S	(6, 7)
# 	L	(7, 8)
# 	.	(8, 9)
# 	.	(9, 10)
# 	F	(10, 11)
# 	[FLM]	(11, 12)
# 	.	(12, 13)
# 	[RK]	(13, 14)
# 	R	(14, 15)
# 	[HRK]	(15, 16)
# 	.	(16, 17)
# 	[RK]	(17, 18)
# 	.	(18, 19)
# 199
#
# Expression Input: ..[RK][RK].SL..F[FLM].[RK]R[HRK].[RK].
# Sequence Input: PIARRASLHRFLEKRKDRIT
# Subequence Match: IARRASLHRFLEKRKDRI
#
# 	.	(1, 2)
# 	.	(2, 3)
# 	[RK]	(3, 4)
# 	[RK]	(4, 5)
# 	.	(5, 6)
# 	S	(6, 7)
# 	L	(7, 8)
# 	.	(8, 9)
# 	.	(9, 10)
# 	F	(10, 11)
# 	[FLM]	(11, 12)
# 	.	(12, 13)
# 	[RK]	(13, 14)
# 	R	(14, 15)
# 	[HRK]	(15, 16)
# 	.	(16, 17)
# 	[RK]	(17, 18)
# 	.	(18, 19)
# 200
#
# Expression Input: ..[RK][RK].SL..F[FLM].[RK]R[HRK].[RK].
# Sequence Input: RIARRASLHRFFAKRKDRAV
# Subequence Match: IARRASLHRFFAKRKDRA
#
# 	.	(1, 2)
# 	.	(2, 3)
# 	[RK]	(3, 4)
# 	[RK]	(4, 5)
# 	.	(5, 6)
# 	S	(6, 7)
# 	L	(7, 8)
# 	.	(8, 9)
# 	.	(9, 10)
# 	F	(10, 11)
# 	[FLM]	(11, 12)
# 	.	(12, 13)
# 	[RK]	(13, 14)
# 	R	(14, 15)
# 	[HRK]	(15, 16)
# 	.	(16, 17)
# 	[RK]	(17, 18)
# 	.	(18, 19)
# 201
#
# Expression Input: ..[RK][RK].SL..F[FLM].[RK]R[HRK].[RK].
# Sequence Input: RIARRASLHRFFAKRKDRAV
# Subequence Match: IARRASLHRFFAKRKDRA
#
# 	.	(1, 2)
# 	.	(2, 3)
# 	[RK]	(3, 4)
# 	[RK]	(4, 5)
# 	.	(5, 6)
# 	S	(6, 7)
# 	L	(7, 8)
# 	.	(8, 9)
# 	.	(9, 10)
# 	F	(10, 11)
# 	[FLM]	(11, 12)
# 	.	(12, 13)
# 	[RK]	(13, 14)
# 	R	(14, 15)
# 	[HRK]	(15, 16)
# 	.	(16, 17)
# 	[RK]	(17, 18)
# 	.	(18, 19)
# 202
#
# Expression Input: ..[RK][RK].SL..F[FLM].[RK]R[HRK].[RK].
# Sequence Input: PLARKASLARFLEKRKERVT
# Subequence Match: LARKASLARFLEKRKERV
#
# 	.	(1, 2)
# 	.	(2, 3)
# 	[RK]	(3, 4)
# 	[RK]	(4, 5)
# 	.	(5, 6)
# 	S	(6, 7)
# 	L	(7, 8)
# 	.	(8, 9)
# 	.	(9, 10)
# 	F	(10, 11)
# 	[FLM]	(11, 12)
# 	.	(12, 13)
# 	[RK]	(13, 14)
# 	R	(14, 15)
# 	[HRK]	(15, 16)
# 	.	(16, 17)
# 	[RK]	(17, 18)
# 	.	(18, 19)
# 203
#
# Expression Input: ..[RK][RK].SL..F[FLM].[RK]R[HRK].[RK].
# Sequence Input: PQARKASLARFLEKRKERLM
# Subequence Match: QARKASLARFLEKRKERL
#
# 	.	(1, 2)
# 	.	(2, 3)
# 	[RK]	(3, 4)
# 	[RK]	(4, 5)
# 	.	(5, 6)
# 	S	(6, 7)
# 	L	(7, 8)
# 	.	(8, 9)
# 	.	(9, 10)
# 	F	(10, 11)
# 	[FLM]	(11, 12)
# 	.	(12, 13)
# 	[RK]	(13, 14)
# 	R	(14, 15)
# 	[HRK]	(15, 16)
# 	.	(16, 17)
# 	[RK]	(17, 18)
# 	.	(18, 19)
# 204
#
# Expression Input: ..[RK][RK].SL..F[FLM].[RK]R[HRK].[RK].
# Sequence Input: PIARRKSLQRFLEKRKERLV
# Subequence Match: IARRKSLQRFLEKRKERL
#
# 	.	(1, 2)
# 	.	(2, 3)
# 	[RK]	(3, 4)
# 	[RK]	(4, 5)
# 	.	(5, 6)
# 	S	(6, 7)
# 	L	(7, 8)
# 	.	(8, 9)
# 	.	(9, 10)
# 	F	(10, 11)
# 	[FLM]	(11, 12)
# 	.	(12, 13)
# 	[RK]	(13, 14)
# 	R	(14, 15)
# 	[HRK]	(15, 16)
# 	.	(16, 17)
# 	[RK]	(17, 18)
# 	.	(18, 19)
# 205
#
# Expression Input: [LIVMP].{0,2}(T)P..([ST])
# Sequence Input: SPLPSGLLTPPQSGKKQSSG
# Subequence Match: LLTPPQS
#
# 	[LIVMP]	(6, 7)
# 	.{1}	(7, 8)
# 	T	(8, 9)
# 	P	(9, 10)
# 	.	(10, 11)
# 	.	(11, 12)
# 	[ST]	(12, 13)
# 206
#
# Expression Input: [LIVMP].{0,2}(T)P..([ST])
# Sequence Input: SPLPSGLLTPPQSGKKQSSG
# Subequence Match: LLTPPQS
#
# 	[LIVMP]	(6, 7)
# 	.{1}	(7, 8)
# 	T	(8, 9)
# 	P	(9, 10)
# 	.	(10, 11)
# 	.	(11, 12)
# 	[ST]	(12, 13)
# 207
#
# Expression Input: [LIVMP].{0,2}(T)P..([ST])
# Sequence Input: QTVPEMPGETPPLSPIDMES
# Subequence Match: PGETPPLS
#
# 	[LIVMP]	(6, 7)
# 	.{2}	(7, 9)
# 	T	(9, 10)
# 	P	(10, 11)
# 	.	(11, 12)
# 	.	(12, 13)
# 	[ST]	(13, 14)
# 208
#
# Expression Input: [LIVMP].{0,2}(T)P..([ST])
# Sequence Input: IWKKFELLPTPPLSPSRRSG
# Subequence Match: LLPTPPLS
#
# 	[LIVMP]	(6, 7)
# 	.{2}	(7, 9)
# 	T	(9, 10)
# 	P	(10, 11)
# 	.	(11, 12)
# 	.	(12, 13)
# 	[ST]	(13, 14)
# 209
#
# Expression Input: [LIVMP].{0,2}(T)P..([ST])
# Sequence Input: KTEVEDTLTPPPSDAGSPFQ
# Subequence Match: LTPPPS
#
# 	[LIVMP]	(7, 8)
# 	.{0}	(8, 8)
# 	T	(8, 9)
# 	P	(9, 10)
# 	.	(10, 11)
# 	.	(11, 12)
# 	[ST]	(12, 13)
# 210
#
# Expression Input: [LIVMP].{0,2}(T)P..([ST])
# Sequence Input: PAGQEEPGTPPSSPLSAEQL
# Subequence Match: PGTPPSS
#
# 	[LIVMP]	(6, 7)
# 	.{1}	(7, 8)
# 	T	(8, 9)
# 	P	(9, 10)
# 	.	(10, 11)
# 	.	(11, 12)
# 	[ST]	(12, 13)
# 211
#
# Expression Input: [LIVMP].{0,2}(T)P..E
# Sequence Input: ICRGFTCFKKPPTPPPEPET
# Subequence Match: PPTPPPE
#
# 	[LIVMP]	(10, 11)
# 	.{1}	(11, 12)
# 	T	(12, 13)
# 	P	(13, 14)
# 	.	(14, 15)
# 	.	(15, 16)
# 	E	(16, 17)
# 212
#
# Expression Input: [LIVMP].{0,2}(T)P..E
# Sequence Input: LQVPEHPFLTPSPESPDQWS
# Subequence Match: PFLTPSPE
#
# 	[LIVMP]	(6, 7)
# 	.{2}	(7, 9)
# 	T	(9, 10)
# 	P	(10, 11)
# 	.	(11, 12)
# 	.	(12, 13)
# 	E	(13, 14)
# 213
#
# Expression Input: ..[DE].(T)P.K
# Sequence Input: GSPNAGSVEQTPKKPGLRRR
# Subequence Match: SVEQTPKK
#
# 	.	(6, 7)
# 	.	(7, 8)
# 	[DE]	(8, 9)
# 	.	(9, 10)
# 	T	(10, 11)
# 	P	(11, 12)
# 	.	(12, 13)
# 	K	(13, 14)
# 214
#
# Expression Input: ..[DE].(T)P.K
# Sequence Input: SPSAAPGVGSVEQTPRKRLR
# Subequence Match: SVEQTPRK
#
# 	.	(9, 10)
# 	.	(10, 11)
# 	[DE]	(11, 12)
# 	.	(12, 13)
# 	T	(13, 14)
# 	P	(14, 15)
# 	.	(15, 16)
# 	K	(16, 17)
# 215
#
# Expression Input: ..[DE].(T)P.K
# Sequence Input: SPNVAPGVGAVEQTPRKRLR
# Subequence Match: AVEQTPRK
#
# 	.	(9, 10)
# 	.	(10, 11)
# 	[DE]	(11, 12)
# 	.	(12, 13)
# 	T	(13, 14)
# 	P	(14, 15)
# 	.	(15, 16)
# 	K	(16, 17)
# 216
#
# Expression Input: .[VLIA][VLI]GWPP[VLI]...R.
# Sequence Input: TRQVAVGWPPLRTYRINSLV
# Subequence Match: VAVGWPPLRTYRI
#
# 	.	(3, 4)
# 	[VLIA]	(4, 5)
# 	[VLI]	(5, 6)
# 	G	(6, 7)
# 	W	(7, 8)
# 	P	(8, 9)
# 	P	(9, 10)
# 	[VLI]	(10, 11)
# 	.	(11, 12)
# 	.	(12, 13)
# 	.	(13, 14)
# 	R	(14, 15)
# 	.	(15, 16)
# 217
#
# Expression Input: .[VLIA][VLI]GWPP[VLI]...R.
# Sequence Input: TSGQVVGWPPIRTYRMNSMV
# Subequence Match: QVVGWPPIRTYRM
#
# 	.	(3, 4)
# 	[VLIA]	(4, 5)
# 	[VLI]	(5, 6)
# 	G	(6, 7)
# 	W	(7, 8)
# 	P	(8, 9)
# 	P	(9, 10)
# 	[VLI]	(10, 11)
# 	.	(11, 12)
# 	.	(12, 13)
# 	.	(13, 14)
# 	R	(14, 15)
# 	.	(15, 16)
# 218
#
# Expression Input: .[VLIA][VLI]GWPP[VLI]...R.
# Sequence Input: RSSQVVGWPPIGLHRMNSLV
# Subequence Match: QVVGWPPIGLHRM
#
# 	.	(3, 4)
# 	[VLIA]	(4, 5)
# 	[VLI]	(5, 6)
# 	G	(6, 7)
# 	W	(7, 8)
# 	P	(8, 9)
# 	P	(9, 10)
# 	[VLI]	(10, 11)
# 	.	(11, 12)
# 	.	(12, 13)
# 	.	(13, 14)
# 	R	(14, 15)
# 	.	(15, 16)
# 219
#
# Expression Input: .[VLIA][VLI]GWPP[VLI]...R.
# Sequence Input: SSSQVVGWPPIGSHRMNSLV
# Subequence Match: QVVGWPPIGSHRM
#
# 	.	(3, 4)
# 	[VLIA]	(4, 5)
# 	[VLI]	(5, 6)
# 	G	(6, 7)
# 	W	(7, 8)
# 	P	(8, 9)
# 	P	(9, 10)
# 	[VLI]	(10, 11)
# 	.	(11, 12)
# 	.	(12, 13)
# 	.	(13, 14)
# 	R	(14, 15)
# 	.	(15, 16)
# 220
#
# Expression Input: .[VLIA][VLI]GWPP[VLI]...R.
# Sequence Input: AKAQVVGWPPVRNYRKNVMA
# Subequence Match: QVVGWPPVRNYRK
#
# 	.	(3, 4)
# 	[VLIA]	(4, 5)
# 	[VLI]	(5, 6)
# 	G	(6, 7)
# 	W	(7, 8)
# 	P	(8, 9)
# 	P	(9, 10)
# 	[VLI]	(10, 11)
# 	.	(11, 12)
# 	.	(12, 13)
# 	.	(13, 14)
# 	R	(14, 15)
# 	.	(15, 16)
# 221
#
# Expression Input: .[VLIA][VLI]GWPP[VLI]...R.
# Sequence Input: TNDQLVGWPPVATARKTVRR
# Subequence Match: QLVGWPPVATARK
#
# 	.	(3, 4)
# 	[VLIA]	(4, 5)
# 	[VLI]	(5, 6)
# 	G	(6, 7)
# 	W	(7, 8)
# 	P	(8, 9)
# 	P	(9, 10)
# 	[VLI]	(10, 11)
# 	.	(11, 12)
# 	.	(12, 13)
# 	.	(13, 14)
# 	R	(14, 15)
# 	.	(15, 16)
# 222
#
# Expression Input: .[VLIA][VLI]GWPP[VLI]...R.
# Sequence Input: AKAQVVGWPPVRSFRKNVMS
# Subequence Match: QVVGWPPVRSFRK
#
# 	.	(3, 4)
# 	[VLIA]	(4, 5)
# 	[VLI]	(5, 6)
# 	G	(6, 7)
# 	W	(7, 8)
# 	P	(8, 9)
# 	P	(9, 10)
# 	[VLI]	(10, 11)
# 	.	(11, 12)
# 	.	(12, 13)
# 	.	(13, 14)
# 	R	(14, 15)
# 	.	(15, 16)
# 223
#
# Expression Input: .[VLIA][VLI]GWPP[VLI]...R.
# Sequence Input: AKAQVVGWPPVRSYRKNVMV
# Subequence Match: QVVGWPPVRSYRK
#
# 	.	(3, 4)
# 	[VLIA]	(4, 5)
# 	[VLI]	(5, 6)
# 	G	(6, 7)
# 	W	(7, 8)
# 	P	(8, 9)
# 	P	(9, 10)
# 	[VLI]	(10, 11)
# 	.	(11, 12)
# 	.	(12, 13)
# 	.	(13, 14)
# 	R	(14, 15)
# 	.	(15, 16)
# 224
#
# Expression Input: .[VLIA][VLI]GWPP[VLI]...R.
# Sequence Input: APGPVVGWPPVRSFRKNLAS
# Subequence Match: PVVGWPPVRSFRK
#
# 	.	(3, 4)
# 	[VLIA]	(4, 5)
# 	[VLI]	(5, 6)
# 	G	(6, 7)
# 	W	(7, 8)
# 	P	(8, 9)
# 	P	(9, 10)
# 	[VLI]	(10, 11)
# 	.	(11, 12)
# 	.	(12, 13)
# 	.	(13, 14)
# 	R	(14, 15)
# 	.	(15, 16)
# 225
#
# Expression Input: .[VLIA][VLI]GWPP[VLI]...R.
# Sequence Input: AKSQVVGWPPVCSYRKKNSC
# Subequence Match: QVVGWPPVCSYRK
#
# 	.	(3, 4)
# 	[VLIA]	(4, 5)
# 	[VLI]	(5, 6)
# 	G	(6, 7)
# 	W	(7, 8)
# 	P	(8, 9)
# 	P	(9, 10)
# 	[VLI]	(10, 11)
# 	.	(11, 12)
# 	.	(12, 13)
# 	.	(13, 14)
# 	R	(14, 15)
# 	.	(15, 16)
# 226
#
# Expression Input: .[VLIA][VLI]GWPP[VLI]...R.
# Sequence Input: AKTQIVGWPPVRSNRKNNNN
# Subequence Match: QIVGWPPVRSNRK
#
# 	.	(3, 4)
# 	[VLIA]	(4, 5)
# 	[VLI]	(5, 6)
# 	G	(6, 7)
# 	W	(7, 8)
# 	P	(8, 9)
# 	P	(9, 10)
# 	[VLI]	(10, 11)
# 	.	(11, 12)
# 	.	(12, 13)
# 	.	(13, 14)
# 	R	(14, 15)
# 	.	(15, 16)
# 227
#
# Expression Input: .[VLIA][VLI]GWPP[VLI]...R.
# Sequence Input: APGPVVGWPPVRSFRKNLAS
# Subequence Match: PVVGWPPVRSFRK
#
# 	.	(3, 4)
# 	[VLIA]	(4, 5)
# 	[VLI]	(5, 6)
# 	G	(6, 7)
# 	W	(7, 8)
# 	P	(8, 9)
# 	P	(9, 10)
# 	[VLI]	(10, 11)
# 	.	(11, 12)
# 	.	(12, 13)
# 	.	(13, 14)
# 	R	(14, 15)
# 	.	(15, 16)
# 228
#
# Expression Input: .[VLIA][VLI]GWPP[VLI]...R.
# Sequence Input: SKAQVVGWPPIRSFRKNSMA
# Subequence Match: QVVGWPPIRSFRK
#
# 	.	(3, 4)
# 	[VLIA]	(4, 5)
# 	[VLI]	(5, 6)
# 	G	(6, 7)
# 	W	(7, 8)
# 	P	(8, 9)
# 	P	(9, 10)
# 	[VLI]	(10, 11)
# 	.	(11, 12)
# 	.	(12, 13)
# 	.	(13, 14)
# 	R	(14, 15)
# 	.	(15, 16)
# 229
#
# Expression Input: .[VLIA][VLI]GWPP[VLI]...R.
# Sequence Input: EVAPVVGWPPVRSSRRNLTA
# Subequence Match: PVVGWPPVRSSRR
#
# 	.	(3, 4)
# 	[VLIA]	(4, 5)
# 	[VLI]	(5, 6)
# 	G	(6, 7)
# 	W	(7, 8)
# 	P	(8, 9)
# 	P	(9, 10)
# 	[VLI]	(10, 11)
# 	.	(11, 12)
# 	.	(12, 13)
# 	.	(13, 14)
# 	R	(14, 15)
# 	.	(15, 16)
# 230
#
# Expression Input: .[VLIA][VLI]GWPP[VLI]...R.
# Sequence Input: TKTQIVGWPPVRSSRKNNNS
# Subequence Match: QIVGWPPVRSSRK
#
# 	.	(3, 4)
# 	[VLIA]	(4, 5)
# 	[VLI]	(5, 6)
# 	G	(6, 7)
# 	W	(7, 8)
# 	P	(8, 9)
# 	P	(9, 10)
# 	[VLI]	(10, 11)
# 	.	(11, 12)
# 	.	(12, 13)
# 	.	(13, 14)
# 	R	(14, 15)
# 	.	(15, 16)
# 231
#
# Expression Input: .[VLIA][VLI]GWPP[VLI]...R.
# Sequence Input: RKAQIVGWPPVRSYRKNNIQ
# Subequence Match: QIVGWPPVRSYRK
#
# 	.	(3, 4)
# 	[VLIA]	(4, 5)
# 	[VLI]	(5, 6)
# 	G	(6, 7)
# 	W	(7, 8)
# 	P	(8, 9)
# 	P	(9, 10)
# 	[VLI]	(10, 11)
# 	.	(11, 12)
# 	.	(12, 13)
# 	.	(13, 14)
# 	R	(14, 15)
# 	.	(15, 16)
# 232
#
# Expression Input: .[VLIA][VLI]GWPP[VLI]...R.
# Sequence Input: PKAQIVGWPPVRSYRKNNVQ
# Subequence Match: QIVGWPPVRSYRK
#
# 	.	(3, 4)
# 	[VLIA]	(4, 5)
# 	[VLI]	(5, 6)
# 	G	(6, 7)
# 	W	(7, 8)
# 	P	(8, 9)
# 	P	(9, 10)
# 	[VLI]	(10, 11)
# 	.	(11, 12)
# 	.	(12, 13)
# 	.	(13, 14)
# 	R	(14, 15)
# 	.	(15, 16)
# 233
#
# Expression Input: .[VLIA][VLI]GWPP[VLI]...R.
# Sequence Input: AKAKIVGWPPIRSYRKNSLH
# Subequence Match: KIVGWPPIRSYRK
#
# 	.	(3, 4)
# 	[VLIA]	(4, 5)
# 	[VLI]	(5, 6)
# 	G	(6, 7)
# 	W	(7, 8)
# 	P	(8, 9)
# 	P	(9, 10)
# 	[VLI]	(10, 11)
# 	.	(11, 12)
# 	.	(12, 13)
# 	.	(13, 14)
# 	R	(14, 15)
# 	.	(15, 16)
# 234
#
# Expression Input: .[VLIA][VLI]GWPP[VLI]...R.
# Sequence Input: KKSQVVGWPPVCSYRRKNSL
# Subequence Match: QVVGWPPVCSYRR
#
# 	.	(3, 4)
# 	[VLIA]	(4, 5)
# 	[VLI]	(5, 6)
# 	G	(6, 7)
# 	W	(7, 8)
# 	P	(8, 9)
# 	P	(9, 10)
# 	[VLI]	(10, 11)
# 	.	(11, 12)
# 	.	(12, 13)
# 	.	(13, 14)
# 	R	(14, 15)
# 	.	(15, 16)
# 235
#
# Expression Input: .[VLIA][VLI]GWPP[VLI]...R.
# Sequence Input: VKSQAVGWPPVCSYRRKKNN
# Subequence Match: QAVGWPPVCSYRR
#
# 	.	(3, 4)
# 	[VLIA]	(4, 5)
# 	[VLI]	(5, 6)
# 	G	(6, 7)
# 	W	(7, 8)
# 	P	(8, 9)
# 	P	(9, 10)
# 	[VLI]	(10, 11)
# 	.	(11, 12)
# 	.	(12, 13)
# 	.	(13, 14)
# 	R	(14, 15)
# 	.	(15, 16)
# 236
#
# Expression Input: .[VLIA][VLI]GWPP[VLI]...R.
# Sequence Input: KKNQVVGWPPVCSYRKKNMN
# Subequence Match: QVVGWPPVCSYRK
#
# 	.	(3, 4)
# 	[VLIA]	(4, 5)
# 	[VLI]	(5, 6)
# 	G	(6, 7)
# 	W	(7, 8)
# 	P	(8, 9)
# 	P	(9, 10)
# 	[VLI]	(10, 11)
# 	.	(11, 12)
# 	.	(12, 13)
# 	.	(13, 14)
# 	R	(14, 15)
# 	.	(15, 16)
# 237
#
# Expression Input: .[VLIA][VLI]GWPP[VLI]...R.
# Sequence Input: AKAQVVGWPPVRNYRKNMMT
# Subequence Match: QVVGWPPVRNYRK
#
# 	.	(3, 4)
# 	[VLIA]	(4, 5)
# 	[VLI]	(5, 6)
# 	G	(6, 7)
# 	W	(7, 8)
# 	P	(8, 9)
# 	P	(9, 10)
# 	[VLI]	(10, 11)
# 	.	(11, 12)
# 	.	(12, 13)
# 	.	(13, 14)
# 	R	(14, 15)
# 	.	(15, 16)
# 238
#
# Expression Input: .[VLIA][VLI]GWPP[VLI]...R.
# Sequence Input: AKAQVVGWPPIRSYRKNTMA
# Subequence Match: QVVGWPPIRSYRK
#
# 	.	(3, 4)
# 	[VLIA]	(4, 5)
# 	[VLI]	(5, 6)
# 	G	(6, 7)
# 	W	(7, 8)
# 	P	(8, 9)
# 	P	(9, 10)
# 	[VLI]	(10, 11)
# 	.	(11, 12)
# 	.	(12, 13)
# 	.	(13, 14)
# 	R	(14, 15)
# 	.	(15, 16)
# 239
#
# Expression Input: .[VLIA][VLI]GWPP[VLI]...R.
# Sequence Input: AKAQIVGWPPVRSYRKNTLA
# Subequence Match: QIVGWPPVRSYRK
#
# 	.	(3, 4)
# 	[VLIA]	(4, 5)
# 	[VLI]	(5, 6)
# 	G	(6, 7)
# 	W	(7, 8)
# 	P	(8, 9)
# 	P	(9, 10)
# 	[VLI]	(10, 11)
# 	.	(11, 12)
# 	.	(12, 13)
# 	.	(13, 14)
# 	R	(14, 15)
# 	.	(15, 16)
# ...
# Sequence Input: LKRSAEGSNPPKPLKKLRFD
# Subequence Match: KRSAEGSNPPKPLKKLRF
#
# Expression Input: [KR][KR].{7,15}[^DE]((K[RK])|(RK))(([^DE][KR])|([KR][^DE]))[^DE]
# Sequence Input: GKKYENVVIKRSPRKRGRPR
# Subequence Match: KKYENVVIKRSPRKRGRP
#
# Expression Input: [KR][KR].{7,15}[^DE]((K[RK])|(RK))(([^DE][KR])|([KR][^DE]))[^DE]
# Sequence Input: KRPRDRHDGELGGRKRARGN
# Subequence Match: KRPRDRHDGELGGRKRARG
#
# Expression Input: [KR][KR].{7,15}[^DE]((K[RK])|(RK))(([^DE][KR])|([KR][^DE]))[^DE]
# Sequence Input: KKDSEVAFKKSYPNQTIFKKVRT
# Subequence Match: KKDSEVAFKKSYPNQTIFKKVRT
#
# 	[KR]	(0, 1)
# 	[KR]	(1, 2)
# 	.{7,15}	(2, 17)
# 	[^DE]	(17, 18)
# 	K	(18, 19)
# 	[RK]	(19, 20)
# 	[^DE]	(20, 21)
# 	[KR]	(21, 22)
# 	[^DE]	(22, 23)
# 3312
#
# Expression Input: [^DE]((K[RK])|(RK))[KRP][KR][^DE]
# Sequence Input: HLANLQEVKRRRRRSHVRNR
# Subequence Match: VKRRRR
#
# 	[^DE]	(7, 8)
# 	K	(8, 9)
# 	[RK]	(9, 10)
# 	[KRP]	(10, 11)
# 	[KR]	(11, 12)
# 	[^DE]	(12, 13)
# 3313
#
# Expression Input: [^DE]((K[RK])|(RK))[KRP][KR][^DE]
# Sequence Input: ECISSAMPKKKKPSRLKGDN
# Subequence Match: PKKKKP
#
# 	[^DE]	(7, 8)
# 	K	(8, 9)
# 	[RK]	(9, 10)
# 	[KRP]	(10, 11)
# 	[KR]	(11, 12)
# 	[^DE]	(12, 13)
# 3314
#
# Expression Input: [^DE]((K[RK])|(RK))[KRP][KR][^DE]
# Sequence Input: EPSKPAATRKRRWSAPESRK
# Subequence Match: TRKRRW
#
# 	[^DE]	(7, 8)
# 	[KRP]	(8, 9)
# 	[KR]	(9, 10)
# 	[^DE]	(10, 11)
# 	[KRP]	(11, 12)
# 3315
#
# Expression Input: [^DE]((K[RK])|(RK))[KRP][KR][^DE]
# Sequence Input: HLPLSWRVKRPRTSIGGGLP
# Subequence Match: VKRPRT
#
# 	[^DE]	(7, 8)
# 	K	(8, 9)
# 	[RK]	(9, 10)
# 	[KRP]	(10, 11)
# 	[KR]	(11, 12)
# 	[^DE]	(12, 13)
# 3316
#
# Expression Input: [^DE]((K[RK])|(RK))[KRP][KR][^DE]
# Sequence Input: ERPLTNKLKRKRRPTSGLHP
# Subequence Match: LKRKRR
#
# 	[^DE]	(7, 8)
# 	K	(8, 9)
# 	[RK]	(9, 10)
# 	[KRP]	(10, 11)
# 	[KR]	(11, 12)
# 	[^DE]	(12, 13)
# 3317
#
# Expression Input: [^DE]((K[RK])|(RK))[KRP][KR][^DE]
# Sequence Input: RPLTNKLKRKRRPTSGLHPE
# Subequence Match: LKRKRR
#
# 	[^DE]	(6, 7)
# 	K	(7, 8)
# 	[RK]	(8, 9)
# 	[KRP]	(9, 10)
# 	[KR]	(10, 11)
# 	[^DE]	(11, 12)
# 3318
#
# Expression Input: [^DE]((K[RK])|(RK))[KRP][KR][^DE]
# Sequence Input: EDLLNEPGQPLDLSCKRPRP
# Subequence Match: CKRPRP
#
# 	[^DE]	(14, 15)
# 	K	(15, 16)
# 	[RK]	(16, 17)
# 	[KRP]	(17, 18)
# 	[KR]	(18, 19)
# 	[^DE]	(19, 20)
# 3319
#
# Expression Input: [^DE]((K[RK])|(RK))[KRP][KR][^DE]
# Sequence Input: QELLSVGSKRRRTGGSLRGN
# Subequence Match: SKRRRT
#
# 	[^DE]	(7, 8)
# 	K	(8, 9)
# 	[RK]	(9, 10)
# 	[KRP]	(10, 11)
# 	[KR]	(11, 12)
# 	[^DE]	(12, 13)
# 3320
#
# Expression Input: [^DE]((K[RK])|(RK))[KRP][KR][^DE]
# Sequence Input: DFEEGPSRKRPRLQAQRKFA
# Subequence Match: RKRPRL
#
# 	[^DE]	(7, 8)
# 	K	(8, 9)
# 	[RK]	(9, 10)
# 	[KRP]	(10, 11)
# 	[KR]	(11, 12)
# 	[^DE]	(12, 13)
# 3321
#
# Expression Input: [^DE]((K[RK])|(RK))[KRP][KR][^DE]
# Sequence Input: NRIAASKSRKRKLERIARLE
# Subequence Match: SRKRKL
#
# 	[^DE]	(7, 8)
# 	[KRP]	(8, 9)
# 	[KR]	(9, 10)
# 	[^DE]	(10, 11)
# 	[KRP]	(11, 12)
# 3322
#
# Expression Input: [^DE]((K[RK])|(RK))[KRP][KR][^DE]
# Sequence Input: NRIAASKCRKRKLERIARLE
# Subequence Match: CRKRKL
#
# 	[^DE]	(7, 8)
# 	[KRP]	(8, 9)
# 	[KR]	(9, 10)
# 	[^DE]	(10, 11)
# 	[KRP]	(11, 12)
# 3323
#
# Expression Input: [^DE]((K[RK])|(RK))[KRP][KR][^DE]
# Sequence Input: PPRTPVSRKRPRPAGATGGG
# Subequence Match: RKRPRP
#
# 	[^DE]	(7, 8)
# 	K	(8, 9)
# 	[RK]	(9, 10)
# 	[KRP]	(10, 11)
# 	[KR]	(11, 12)
# 	[^DE]	(12, 13)
# 3324
#
# Expression Input: [^DE]((K[RK])|(RK))[KRP][KR][^DE]
# Sequence Input: SQHSTPPKKKRKVEDPKDFP
# Subequence Match: PKKKRK
#
# 	[^DE]	(6, 7)
# 	K	(7, 8)
# 	[RK]	(8, 9)
# 	[KRP]	(9, 10)
# 	[KR]	(10, 11)
# 	[^DE]	(11, 12)
# 3325
#
# Expression Input: [^DE]((K[RK])|(RK))[KRP][KR][^DE]
# Sequence Input: TSNNRLLNKRRKKQAGSSSA
# Subequence Match: NKRRKK
#
# 	[^DE]	(7, 8)
# 	K	(8, 9)
# 	[RK]	(9, 10)
# 	[KRP]	(10, 11)
# 	[KR]	(11, 12)
# 	[^DE]	(12, 13)
# 3326
#
# Expression Input: [^DE]((K[RK])|(RK))[KRP][KR][^DE]
# Sequence Input: EQSSPRVLRPGDSKRRRKHL
# Subequence Match: SKRRRK
#
# 	[^DE]	(12, 13)
# 	K	(13, 14)
# 	[RK]	(14, 15)
# 	[KRP]	(15, 16)
# 	[KR]	(16, 17)
# 	[^DE]	(17, 18)
# 3327
#
# Expression Input: [^DE]((K[RK])|(RK))[KRP][KR][^DE]
# Sequence Input: ALGISYGRKKRRQRRRAHQN
# Subequence Match: GRKKRR
#
# 	[^DE]	(6, 7)
# 	[KRP]	(7, 8)
# 	[KR]	(8, 9)
# 	[^DE]	(9, 10)
# 	[KRP]	(10, 11)
# 3328
#
# Expression Input: [^DE]((K[RK])|(RK))[KRP][KR][^DE]
# Sequence Input: TPTWATVIEEDGPQKKKRRL
# Subequence Match: QKKKRR
#
# 	[^DE]	(13, 14)
# 	K	(14, 15)
# 	[RK]	(15, 16)
# 	[KRP]	(16, 17)
# 	[KR]	(17, 18)
# 	[^DE]	(18, 19)
# 3329
#
# Expression Input: [^DE]((K[RK])|(RK))[KRP][KR][^DE]
# Sequence Input: GLLWRLRFRKPKSKDCLCWF
# Subequence Match: FRKPKS
#
# 	[^DE]	(7, 8)
# 	[KRP]	(8, 9)
# 	[KR]	(9, 10)
# 	[^DE]	(10, 11)
# 	[KRP]	(11, 12)
# 3330
#
# Expression Input: [^DE]((K[RK])|(RK))(([^DE][KR])|([KR][^DE]))(([PKR])|([^DE][DE]))
# Sequence Input: SEDDEGKKKKKAKKGGKDKK
# Subequence Match: GKKKKK
#
# 	[^DE]	(5, 6)
# 	K	(6, 7)
# 	[RK]	(7, 8)
# 	[^DE]	(8, 9)
# 	[KR]	(9, 10)
# 	[PKR]	(10, 11)
# 3331
#
# Expression Input: [^DE]((K[RK])|(RK))(([^DE][KR])|([KR][^DE]))(([PKR])|([^DE][DE]))
# Sequence Input: ECISSAMPKKKKPSRLKGDN
# Subequence Match: PKKKKP
#
# 	[^DE]	(7, 8)
# 	K	(8, 9)
# 	[RK]	(9, 10)
# 	[^DE]	(10, 11)
# 	[KR]	(11, 12)
# 	[PKR]	(12, 13)
# 3332
#
# Expression Input: [^DE]((K[RK])|(RK))(([^DE][KR])|([KR][^DE]))(([PKR])|([^DE][DE]))
# Sequence Input: RILQASGMKRAKPSPTSTQT
# Subequence Match: MKRAKP
#
# 	[^DE]	(7, 8)
# 	K	(8, 9)
# 	[RK]	(9, 10)
# 	[^DE]	(10, 11)
# 	[KR]	(11, 12)
# 	[PKR]	(12, 13)
# 3333
#
# Expression Input: [^DE]((K[RK])|(RK))(([^DE][KR])|([KR][^DE]))(([PKR])|([^DE][DE]))
# Sequence Input: QTRASSRKRSRSDRAVTGPS
# Subequence Match: SRKRSR
#
# Expression Input: [^DE]((K[RK])|(RK))(([^DE][KR])|([KR][^DE]))(([PKR])|([^DE][DE]))
# Sequence Input: ERPLTNKLKRKRRPTSGLHP
# Subequence Match: LKRKRR
#
# 	[^DE]	(7, 8)
# 	K	(8, 9)
# 	[RK]	(9, 10)
# 	[^DE]	(10, 11)
# 	[KR]	(11, 12)
# 	[PKR]	(12, 13)
# 3334
#
# Expression Input: [^DE]((K[RK])|(RK))(([^DE][KR])|([KR][^DE]))(([PKR])|([^DE][DE]))
# Sequence Input: RPLTNKLKRKRRPTSGLHPE
# Subequence Match: LKRKRR
#
# 	[^DE]	(6, 7)
# 	K	(7, 8)
# 	[RK]	(8, 9)
# 	[^DE]	(9, 10)
# 	[KR]	(10, 11)
# 	[PKR]	(11, 12)
# 3335
#
# Expression Input: [^DE]((K[RK])|(RK))(([^DE][KR])|([KR][^DE]))(([PKR])|([^DE][DE]))
# Sequence Input: SPTITVMKKKVKPQVPTRTS
# Subequence Match: MKKKVK
#
# Expression Input: [^DE]((K[RK])|(RK))(([^DE][KR])|([KR][^DE]))(([PKR])|([^DE][DE]))
# Sequence Input: EDLLNEPGQPLDLSCKRPRP
# Subequence Match: CKRPRP
#
# 	[^DE]	(14, 15)
# 	K	(15, 16)
# 	[RK]	(16, 17)
# 	[^DE]	(17, 18)
# 	[KR]	(18, 19)
# 	[PKR]	(19, 20)
# 3336
#
# Expression Input: [^DE]((K[RK])|(RK))(([^DE][KR])|([KR][^DE]))(([PKR])|([^DE][DE]))
# Sequence Input: KIRLRPGGKKKYKLKHIVWA
# Subequence Match: GKKKYK
#
# Expression Input: [^DE]((K[RK])|(RK))(([^DE][KR])|([KR][^DE]))(([PKR])|([^DE][DE]))
# Sequence Input: KTSTSTDGKKRSKARKETYS
# Subequence Match: GKKRSK
#
# Expression Input: [^DE]((K[RK])|(RK))(([^DE][KR])|([KR][^DE]))(([PKR])|([^DE][DE]))
# Sequence Input: SDFEEGPSRKRPRLQAQRKF
# Subequence Match: SRKRPR
#
# 	[^DE]	(7, 8)
# 	[^DE]	(8, 9)
# 	[KR]	(9, 10)
# 	[PKR]	(10, 11)
# 	[PKR]	(11, 12)
# 3337
#
# Expression Input: [^DE]((K[RK])|(RK))(([^DE][KR])|([KR][^DE]))(([PKR])|([^DE][DE]))
# Sequence Input: RIAASKSRKRKLERIARLEE
# Subequence Match: SRKRKLE
#
# Expression Input: [^DE]((K[RK])|(RK))(([^DE][KR])|([KR][^DE]))(([PKR])|([^DE][DE]))
# Sequence Input: RIAASKCRKRKLERIARLEE
# Subequence Match: CRKRKLE
#
# Expression Input: [^DE]((K[RK])|(RK))(([^DE][KR])|([KR][^DE]))(([PKR])|([^DE][DE]))
# Sequence Input: PPRTPVSRKRPRPAGATGGG
# Subequence Match: SRKRPR
#
# 	[^DE]	(6, 7)
# 	[^DE]	(7, 8)
# 	[KR]	(8, 9)
# 	[PKR]	(9, 10)
# 	[PKR]	(10, 11)
# 3338
#
# Expression Input: [^DE]((K[RK])|(RK))(([^DE][KR])|([KR][^DE]))(([PKR])|([^DE][DE]))
# Sequence Input: QHSTPPKKKRKVEDPKDFPS
# Subequence Match: PKKKRK
#
# 	[^DE]	(5, 6)
# 	K	(6, 7)
# 	[RK]	(7, 8)
# 	[^DE]	(8, 9)
# 	[KR]	(9, 10)
# 	[PKR]	(10, 11)
# 3339
#
# Expression Input: [^DE]((K[RK])|(RK))(([^DE][KR])|([KR][^DE]))(([PKR])|([^DE][DE]))
# Sequence Input: RKDYPAAKRVKLDSVRVLRQ
# Subequence Match: AKRVKLD
#
# Expression Input: [^DE]((K[RK])|(RK))(([^DE][KR])|([KR][^DE]))(([PKR])|([^DE][DE]))
# Sequence Input: IKDKEEVQRKRQKLMPNFSD
# Subequence Match: QRKRQK
#
# Expression Input: [^DE]((K[RK])|(RK))(([^DE][KR])|([KR][^DE]))(([PKR])|([^DE][DE]))
# Sequence Input: SNSSPYLNKRRGKPGPDSAT
# Subequence Match: NKRRGK
#
# Expression Input: [^DE]((K[RK])|(RK))(([^DE][KR])|([KR][^DE]))(([PKR])|([^DE][DE]))
# Sequence Input: KSKFKFSQRKAKKKGPGMTH
# Subequence Match: QRKAKK
#
# 	[^DE]	(7, 8)
# 	[^DE]	(8, 9)
# 	[KR]	(9, 10)
# 	[^DE]	(10, 11)
# 	[KR]	(11, 12)
# 	[PKR]	(12, 13)
# 3340
#
# Expression Input: [^DE]((K[RK])|(RK))(([^DE][KR])|([KR][^DE]))(([PKR])|([^DE][DE]))
# Sequence Input: RRRPRRSQRKRPPTPWPTSQ
# Subequence Match: QRKRPP
#
# 	[^DE]	(7, 8)
# 	[^DE]	(8, 9)
# 	[KR]	(9, 10)
# 	[PKR]	(10, 11)
# 	[PKR]	(11, 12)
# 3341
#
# Expression Input: [^DE]((K[RK])|(RK))(([^DE][KR])|([KR][^DE]))(([PKR])|([^DE][DE]))
# Sequence Input: RHRIEEKRKRTYETFKSIMK
# Subequence Match: KRKRTYE
#
# Expression Input: [^DE]((K[RK])|(RK))(([^DE][KR])|([KR][^DE]))(([PKR])|([^DE][DE]))
# Sequence Input: NQLEYLSRKGKLELQRSARH
# Subequence Match: SRKGKLE
#
# Expression Input: [^DE]((K[RK])|(RK))(([^DE][KR])|([KR][^DE]))(([PKR])|([^DE][DE]))
# Sequence Input: TPTWATVIEEDGPQKKKRRL
# Subequence Match: QKKKRR
#
# 	[^DE]	(13, 14)
# 	K	(14, 15)
# 	[RK]	(15, 16)
# 	[^DE]	(16, 17)
# 	[KR]	(17, 18)
# 	[PKR]	(18, 19)
# 3342
#
# Expression Input: (([PKR].{0,1}[^DE])|([PKR]))((K[RK])|(RK))(([^DE][KR])|([KR][^DE]))[^DE]
# Sequence Input: GTMLALPEKKKTKARSAEKA
# Subequence Match: PEKKKTKA
#
# 	[PKR]	(6, 7)
# 	.{1}	(7, 8)
# 	[^DE]	(8, 9)
# 	K	(9, 10)
# 	[RK]	(10, 11)
# 	[^DE]	(11, 12)
# 	[KR]	(12, 13)
# 	[^DE]	(13, 14)
# 3343
#
# Expression Input: (([PKR].{0,1}[^DE])|([PKR]))((K[RK])|(RK))(([^DE][KR])|([KR][^DE]))[^DE]
# Sequence Input: CISSAMPKKKKPSRLKGDNE
# Subequence Match: PKKKKPS
#
# 	[PKR]	(6, 7)
# 	.{1}	(7, 8)
# 	[^DE]	(8, 9)
# 	K	(9, 10)
# 	[RK]	(10, 11)
# 	[^DE]	(11, 12)
# 	[^DE]	(12, 13)
# 3344
#
# Expression Input: (([PKR].{0,1}[^DE])|([PKR]))((K[RK])|(RK))(([^DE][KR])|([KR][^DE]))[^DE]
# Sequence Input: CISSAMPKKKKPSRLKGDNE
# Subequence Match: PKKKKPS
#
# 	[PKR]	(6, 7)
# 	.{1}	(7, 8)
# 	[^DE]	(8, 9)
# 	K	(9, 10)
# 	[RK]	(10, 11)
# 	[^DE]	(11, 12)
# 	[^DE]	(12, 13)
# 3345
#
# Expression Input: (([PKR].{0,1}[^DE])|([PKR]))((K[RK])|(RK))(([^DE][KR])|([KR][^DE]))[^DE]
# Sequence Input: ERPLTNKLKRKRRPTSGLHP
# Subequence Match: KLKRKRRP
#
# 	[PKR]	(6, 7)
# 	.{1}	(7, 8)
# 	[^DE]	(8, 9)
# 	[^DE]	(9, 10)
# 	[KR]	(10, 11)
# 	[^DE]	(11, 12)
# 	[KR]	(12, 13)
# 	[^DE]	(13, 14)
# 3346
#
# Expression Input: (([PKR].{0,1}[^DE])|([PKR]))((K[RK])|(RK))(([^DE][KR])|([KR][^DE]))[^DE]
# Sequence Input: PLTNKLKRKRRPTSGLHPED
# Subequence Match: KLKRKRRP
#
# 	[PKR]	(4, 5)
# 	.{1}	(5, 6)
# 	[^DE]	(6, 7)
# 	[^DE]	(7, 8)
# 	[KR]	(8, 9)
# 	[^DE]	(9, 10)
# 	[KR]	(10, 11)
# 	[^DE]	(11, 12)
# 3347
#
# Expression Input: (([PKR].{0,1}[^DE])|([PKR]))((K[RK])|(RK))(([^DE][KR])|([KR][^DE]))[^DE]
# Sequence Input: NIHNSKAPKKNRLRRKSSTR
# Subequence Match: KAPKKNRL
#
# 	[PKR]	(5, 6)
# 	.{1}	(6, 7)
# 	[^DE]	(7, 8)
# 	K	(8, 9)
# 	[RK]	(9, 10)
# 	[^DE]	(10, 11)
# 	[KR]	(11, 12)
# 	[^DE]	(12, 13)
# 3348
#
# Expression Input: (([PKR].{0,1}[^DE])|([PKR]))((K[RK])|(RK))(([^DE][KR])|([KR][^DE]))[^DE]
# Sequence Input: AMICYRKKRKGKLTLEDQAT
# Subequence Match: RKKRKGKL
#
# 	[PKR]	(5, 6)
# 	.{1}	(6, 7)
# 	[^DE]	(7, 8)
# 	[^DE]	(8, 9)
# 	[KR]	(9, 10)
# 	[^DE]	(10, 11)
# 	[KR]	(11, 12)
# 	[^DE]	(12, 13)
# 3349
#
# Expression Input: (([PKR].{0,1}[^DE])|([PKR]))((K[RK])|(RK))(([^DE][KR])|([KR][^DE]))[^DE]
# Sequence Input: TSTSTDGKKRSKARKETYSS
# Subequence Match: KKRSKA
#
# Expression Input: (([PKR].{0,1}[^DE])|([PKR]))((K[RK])|(RK))(([^DE][KR])|([KR][^DE]))[^DE]
# Sequence Input: DFEEGPSRKRPRLQAQRKFA
# Subequence Match: PSRKRPRL
#
# 	[PKR]	(5, 6)
# 	.{1}	(6, 7)
# 	[^DE]	(7, 8)
# 	K	(8, 9)
# 	[RK]	(9, 10)
# 	[^DE]	(10, 11)
# 	[KR]	(11, 12)
# 	[^DE]	(12, 13)
# 3350
#
# Expression Input: (([PKR].{0,1}[^DE])|([PKR]))((K[RK])|(RK))(([^DE][KR])|([KR][^DE]))[^DE]
# Sequence Input: NRIAASKSRKRKLERIARLE
# Subequence Match: KSRKRKL
#
# 	[PKR]	(6, 7)
# 	.{1}	(7, 8)
# 	[^DE]	(8, 9)
# 	K	(9, 10)
# 	[RK]	(10, 11)
# 	[^DE]	(11, 12)
# 	[^DE]	(12, 13)
# 3351
#
# Expression Input: (([PKR].{0,1}[^DE])|([PKR]))((K[RK])|(RK))(([^DE][KR])|([KR][^DE]))[^DE]
# Sequence Input: NRIAASKCRKRKLERIARLE
# Subequence Match: KCRKRKL
#
# 	[PKR]	(6, 7)
# 	.{1}	(7, 8)
# 	[^DE]	(8, 9)
# 	K	(9, 10)
# 	[RK]	(10, 11)
# 	[^DE]	(11, 12)
# 	[^DE]	(12, 13)
# 3352
#
# Expression Input: (([PKR].{0,1}[^DE])|([PKR]))((K[RK])|(RK))(([^DE][KR])|([KR][^DE]))[^DE]
# Sequence Input: PPRTPVSRKRPRPAGATGGG
# Subequence Match: PVSRKRPR
#
# 	[PKR]	(4, 5)
# 	.{1}	(5, 6)
# 	[^DE]	(6, 7)
# 	[^DE]	(7, 8)
# 	[KR]	(8, 9)
# 	[^DE]	(9, 10)
# 	[^DE]	(10, 11)
# 	[KR]	(11, 12)
# 3353
#
# Expression Input: (([PKR].{0,1}[^DE])|([PKR]))((K[RK])|(RK))(([^DE][KR])|([KR][^DE]))[^DE]
# Sequence Input: SQHSTPPKKKRKVEDPKDFP
# Subequence Match: PPKKKRKV
#
# 	[PKR]	(5, 6)
# 	.{1}	(6, 7)
# 	[^DE]	(7, 8)
# 	K	(8, 9)
# 	[RK]	(9, 10)
# 	[^DE]	(10, 11)
# 	[KR]	(11, 12)
# 	[^DE]	(12, 13)
# 3354
#
# Expression Input: (([PKR].{0,1}[^DE])|([PKR]))((K[RK])|(RK))(([^DE][KR])|([KR][^DE]))[^DE]
# Sequence Input: SQHSTPPKKKRKVEDPKDFP
# Subequence Match: PPKKKRKV
#
# 	[PKR]	(5, 6)
# 	.{1}	(6, 7)
# 	[^DE]	(7, 8)
# 	K	(8, 9)
# 	[RK]	(9, 10)
# 	[^DE]	(10, 11)
# 	[KR]	(11, 12)
# 	[^DE]	(12, 13)
# 3355
#
# Expression Input: (([PKR].{0,1}[^DE])|([PKR]))((K[RK])|(RK))(([^DE][KR])|([KR][^DE]))[^DE]
# Sequence Input: STRKDYPAAKRVKLDSVRVL
# Subequence Match: PAAKRVKL
#
# 	[PKR]	(6, 7)
# 	.{1}	(7, 8)
# 	[^DE]	(8, 9)
# 	K	(9, 10)
# 	[RK]	(10, 11)
# 	[^DE]	(11, 12)
# 	[KR]	(12, 13)
# 	[^DE]	(13, 14)
# 3356
#
# Expression Input: (([PKR].{0,1}[^DE])|([PKR]))((K[RK])|(RK))(([^DE][KR])|([KR][^DE]))[^DE]
# Sequence Input: KDKEEVQRKRQKLMPNFSDS
# Subequence Match: RKRQKL
#
# Expression Input: (([PKR].{0,1}[^DE])|([PKR]))((K[RK])|(RK))(([^DE][KR])|([KR][^DE]))[^DE]
# Sequence Input: SRHAQEPPAKRRKGSKGPEG
# Subequence Match: PPAKRRKG
#
# 	[PKR]	(6, 7)
# 	.{1}	(7, 8)
# 	[^DE]	(8, 9)
# 	K	(9, 10)
# 	[RK]	(10, 11)
# 	[^DE]	(11, 12)
# 	[KR]	(12, 13)
# 	[^DE]	(13, 14)
# 3357
#
# Expression Input: (([PKR].{0,1}[^DE])|([PKR]))((K[RK])|(RK))(([^DE][KR])|([KR][^DE]))[^DE]
# Sequence Input: EADHGKARKRLKAHHGRDNN
# Subequence Match: KARKRLKA
#
# 	[PKR]	(5, 6)
# 	.{1}	(6, 7)
# 	[^DE]	(7, 8)
# 	K	(8, 9)
# 	[RK]	(9, 10)
# 	[^DE]	(10, 11)
# 	[KR]	(11, 12)
# 	[^DE]	(12, 13)
# 3358
#
# Expression Input: (([PKR].{0,1}[^DE])|([PKR]))((K[RK])|(RK))(([^DE][KR])|([KR][^DE]))[^DE]
# Sequence Input: RSKNDSKLKKKSALQSKFKE
# Subequence Match: KLKKKSA
#
# 	[PKR]	(6, 7)
# 	.{1}	(7, 8)
# 	[^DE]	(8, 9)
# 	K	(9, 10)
# 	[RK]	(10, 11)
# 	[^DE]	(11, 12)
# 	[^DE]	(12, 13)
# 3359
#
# Expression Input: (([PKR].{0,1}[^DE])|([PKR]))((K[RK])|(RK))(([^DE][KR])|([KR][^DE]))[^DE]
# Sequence Input: MPSRFTKTRKHRGHVSAGKG
# Subequence Match: KTRKHRG
#
# Expression Input: (([PKR].{0,1}[^DE])|([PKR]))((K[RK])|(RK))(([^DE][KR])|([KR][^DE]))[^DE]
# Sequence Input: GHPESPPRKRLKSKGSDKDF
# Subequence Match: PPRKRLKS
#
# 	[PKR]	(5, 6)
# 	.{1}	(6, 7)
# 	[^DE]	(7, 8)
# 	K	(8, 9)
# 	[RK]	(9, 10)
# 	[^DE]	(10, 11)
# 	[KR]	(11, 12)
# 	[^DE]	(12, 13)
# 3360
#
# Expression Input: (([PKR].{0,1}[^DE])|([PKR]))((K[RK])|(RK))(([^DE][KR])|([KR][^DE]))[^DE]
# Sequence Input: MNSPGGRGKKKGSGGASNPV
# Subequence Match: RGKKKGS
#
# 	[PKR]	(6, 7)
# 	.{1}	(7, 8)
# 	[^DE]	(8, 9)
# 	K	(9, 10)
# 	[RK]	(10, 11)
# 	[^DE]	(11, 12)
# 	[^DE]	(12, 13)
# 3361
#
# Expression Input: (([PKR].{0,1}[^DE])|([PKR]))((K[RK])|(RK))(([^DE][KR])|([KR][^DE]))[^DE]
# Sequence Input: HRELGSPLKKLKIDTSVIDA
# Subequence Match: PLKKLKI
#
# Expression Input: (([PKR].{0,1}[^DE])|([PKR]))((K[RK])|(RK))(([^DE][KR])|([KR][^DE]))[^DE]
# Sequence Input: SFFSPSPARKRHAPSPEPAV
# Subequence Match: PARKRHA
#
# 	[PKR]	(6, 7)
# 	.{1}	(7, 8)
# 	[^DE]	(8, 9)
# 	K	(9, 10)
# 	[RK]	(10, 11)
# 	[^DE]	(11, 12)
# 	[^DE]	(12, 13)
# 3362
#
# Expression Input: (([PKR].{0,1}[^DE])|([PKR]))((K[RK])|(RK))(([^DE][KR])|([KR][^DE]))[^DE]
# Sequence Input: MAPKRKSGVSKCETKCTKAC
# Subequence Match: PKRKSG
#
# Expression Input: (([PKR].{0,1}[^DE])|([PKR]))((K[RK])|(RK))(([^DE][KR])|([KR][^DE]))[^DE]
# Sequence Input: TPTWATVIEEDGPQKKKRRL
# Subequence Match: PQKKKRRL
#
# 	[PKR]	(12, 13)
# 	.{1}	(13, 14)
# 	[^DE]	(14, 15)
# 	K	(15, 16)
# 	[RK]	(16, 17)
# 	[^DE]	(17, 18)
# 	[KR]	(18, 19)
# 	[^DE]	(19, 20)
# 3363
#
# Expression Input: (([PKR].{0,1}[^DE])|([PKR]))((K[RK])|(RK))(([^DE][KR])|([KR][^DE]))[^DE]
# Sequence Input: DSEDSVTFEFVPNTKKQKCG
# Subequence Match: PNTKKQKC
#
# 	[PKR]	(11, 12)
# 	.{1}	(12, 13)
# 	[^DE]	(13, 14)
# 	K	(14, 15)
# 	[RK]	(15, 16)
# 	[^DE]	(16, 17)
# 	[KR]	(17, 18)
# 	[^DE]	(18, 19)
# 3364
#
# Expression Input: (([PKR].{0,1}[^DE])|([PKR]))((K[RK])|(RK))(([^DE][KR])|([KR][^DE]))[^DE]
# Sequence Input: MFEDHPPTKKARVSMRRMSN
# Subequence Match: PPTKKARV
#
# 	[PKR]	(5, 6)
# 	.{1}	(6, 7)
# 	[^DE]	(7, 8)
# 	K	(8, 9)
# 	[RK]	(9, 10)
# 	[^DE]	(10, 11)
# 	[KR]	(11, 12)
# 	[^DE]	(12, 13)
# 3365
#
# Expression Input: (R.[LI].[EDQ])|(R.L..[EDQ])|(K.L.E)
# Sequence Input: DYGFRESRILAEGEDTCARK
# Subequence Match: RILAE
